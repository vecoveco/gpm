# %%
import h5py
import numpy as np
import matplotlib.pyplot as pl
import wradlib
from osgeo import osr
import datetime as dt
import glob
from osgeo import gdal
from scipy.spatial import cKDTree

% matplotlib inline 

#from pcc import get_time_of_gpm
import datetime as dt

# %% [markdown]
# ### Used Functions
# -----------------

# %%
def dpr_swath_contour(sr_grid):
    """

    Function for dpr swath grid contour
    
    ## sr_grid[:, 0]        # - complete left column
    ## sr_grid[-1,1:-1]     # - upper edge without left and right corner
    ## sr_grid[:, -1][::-1] # - complete right column (backward)
    ## sr_grid[0,0:-1]      # - lower edge (without right corner)
    
    Input:
    ------
    sr_grid ::: Space-borne grid x,y
    
    Output:
    -------
    trg ::: Contour of the space-borne grid
    
    """
    
    trg = np.r_[sr_grid[:, 0], sr_grid[-1, 1:-1], sr_grid[:, -1][::-1], sr_grid[0, 0:-1][::-1]]
    
    return trg

# %%
def idx_sr_in_gr_area(_bingrid, _gpm_xy):
    """
    Funktion:
    ---------
    Search for SR Footprint (Index) that are located in the GR scan area 
    
    Input: 
    ------
    _bingrid ::: Binary-grid of the GR scan area
        
    _gpm_xy ::: GPM footptint coordinates
    
    Output:
    -------
    
    _gpm_xy_outer_idx ::: index of all footprints not included in radolan scan area
    _gpm_xy_inner_idx ::: idex of all footprints included in radolan area but
                           not scanned by ground radars 
    
    """
    _gpm_xy = _gpm_xy.copy()
    # Bestimmen von Eckpunkten bei RADOLAN RY GRID!
    # HARDCODED: but ok for regula RADOLAN Produkts
    xmin, xmax = -523.4621669218559, 375.5378330781441
    ymin, ymax = -4658.644724265572, -3759.644724265572
    
    # Radolangitter um 1 gridpoit zu allen seiten erweitern
    _xex, _yex = np.arange(xmin-1, xmax+2, 1), np.arange(ymin-1, ymax+2, 1)
    _xxx, _yyy = np.meshgrid(_xex,_yex)
    
    # Bin grid bestimmen
    _bingrid = _bingrid.copy()
    _bingrid[_bingrid >= 0]=1
    _bingrid[_bingrid < 0]=0
    
    # Gittererweiterungen zusammenstellen
    ## rn_tb ::: bin gird top and bottom
    ## rn_lr ::: bin gird left and right
    rn_tb = np.zeros(900)
    rn_lr = np.zeros(902)
    
    # Griderweiterungen einsetzen
    # erst oben und unten
    rn1 = np.c_[rn_tb, _bingrid, rn_tb]
    # dann rechts
    rn2 = np.vstack((rn1, rn_lr))
    # dann rechts
    rn3 = np.vstack((rn_lr,rn2))
    
    from skimage import measure
    # Contouren des Bin-grids erstellen
    contours = measure.find_contours(rn3, 0, positive_orientation='high',
                                     fully_connected='high' )
    ### print(len(contours), ' detected Polygons')
    #print("---------------------")
    #for j in range(len(contours)):
    #    print(len(contours[j]))
    #print("---------------------")

    # bestiimung der Listen für Polygon Points
    _xx = []
    _yy = []

    # suche nach dem größten Polygon... dieser sollte der RADOLAN UMRISS sein
    for i in range(len(contours)):
        # Polygone mit 3 oder weniger points ergeben keine nutzbare Fläche
        if len(_xxx[contours[i][:,0].astype(int),contours[i][:,1].astype(int)]) <= 3:
            print('not relevant polygon removed')
        else:   
            # PolygonPoints bestimmen (RADOLAN RAND POINTS)
            _xx.append(_xxx[contours[i][:,0].astype(int),contours[i][:,1].astype(int)])
            _yy.append(_yyy[contours[i][:,0].astype(int),contours[i][:,1].astype(int)])
            
    # sortiern nach der länge, das letzt element ist das größte und sollte somit der Radolarand sein
    _xx.sort(key=len)
    _yy.sort(key=len)

    # Outter polygon erstellen
    _xy = np.vstack((_xx[-1].ravel(), _yy[-1].ravel())).transpose()    
    
    # Suche nach den GPM footprints im Scanngebiet von RADOLAN mit ZONALSTATS
    zdpoly = wradlib.zonalstats.ZonalDataPoly(_gpm_xy, [_xy])
    _gpm_xy_outer_idx = zdpoly.get_source_index(0)
    
    # Array for inner Polygons
    _gpm_xy_inner_idx = np.array([])
    
    # Entferne Inner Polygons
    # Auch nur wenn es weitere Polygone gibt 
    if len(_xx)>1:

        for inner_poly_index in range(len(_xx)-1):

            ### print ('Polygon size: ', len(_xx[inner_poly_index].ravel()))

            _xy_inner = np.vstack((_xx[inner_poly_index].ravel(),
                                  _yy[inner_poly_index].ravel())).transpose()

            _zdpoly = wradlib.zonalstats.ZonalDataPoly(_gpm_xy, [_xy_inner])

            _inner_idx = _zdpoly.get_source_index(0)

            _gpm_xy_inner_idx = np.append(_gpm_xy_inner_idx, _inner_idx)


            ### if _gpm_xy_inner_idx.size==0:
                ### print ('inner polygons do not match with SR grid')

            ### else:
                ### print('match idx with inner polygon: ', _gpm_xy_inner_idx.shape)
                    

    
    _idx_r = ~np.isin(_gpm_xy_outer_idx, _gpm_xy_inner_idx)
    
    return _gpm_xy_outer_idx[_idx_r]

# %%
def dpr_antenna_weighting(r):
    """
    Funktion: explained in 
    Watters, D., A. Battaglia, K. Mroz, and F. Tridon, 0: 
    Validation of the GPM Version-5 Surface Rainfall 
    Products over Great Britain and Ireland. 
    J. Hydrometeor., 0, https://doi.org/10.1175/JHM-D-18-0051.1
    
    and
    
    Mroz, K., A. Battaglia, T. J. Lang, D. J. Cecil, 
    S. Tanelli, and F. Tridon, 2017:  Hail-detection
    algorithm for the GPM Core Observatory satellite sensors.
    Journal of Applied Meteorology and Climatology,56 (7), 1939–1957
    
    Input:
    ------
    r ::: Distance to the center point of the footprint
    
    Output:
    -------
    omega ::: Weighting for the point with the distance
    
    """
    
    omega = np.exp(-(r/2.5)**2. * np.log10(4.))
    
    return omega

# %%
def ipoli_radi_w(xy_cut, gpm_xy,rwdata_cut, dpr_footprint, k=25):
    """
    ...
    """
    # cKDTree radolan
    tree = cKDTree(xy_cut, balanced_tree=False)

    # cKDTree gpm dpr
    tree_gpm = cKDTree(gpm_xy, balanced_tree=True)

    dists, ix = tree.query(gpm_xy, k=k, n_jobs=-1) # k maximal possible ry pixel in dpr footprint
    ix2 = tree.query_ball_point(gpm_xy, dpr_footprint)

    ry_pns_w = []

    for i in range(ix.shape[0]):
        #i is all points in one dpr footprint
        #distancen for all i
        index = np.isin(ix[i,:],ix2[i] )
        res1 = np.nansum( dpr_antenna_weighting(dists[i,:][index]) * rwdata_cut.ravel()[ix[i,:][index]])
        res2 = np.nansum(dpr_antenna_weighting(dists[i,:][index]))

        ry_pns_w.append(res1/res2)


    return np.array(ry_pns_w)

# %%
def ipoli_radi(xy_cut, gpm_xy,rwdata_cut, dpr_footprint, k=25, calc='mean'):
    """
    calc: mean, max, min
    """
    # cKDTree radolan
    tree = cKDTree(xy_cut, balanced_tree=False)

    # cKDTree gpm dpr
    tree_gpm = cKDTree(gpm_xy, balanced_tree=True)

    dists, ix = tree.query(gpm_xy, k=k, n_jobs=-1) # k maximal possible ry pixel in dpr footprint
    ix2 = tree.query_ball_point(gpm_xy, dpr_footprint)

    ry_par = []
    
    if calc=='mean':

        for i in range(ix.shape[0]):
            #i is all points in one dpr footprint
            #distancen for all i
            index = np.isin(ix[i,:],ix2[i] )
            res1 = np.nanmean(rwdata_cut.ravel()[ix[i,:][index]])
            ry_par.append(res1)
            
    elif calc=='max':

            for i in range(ix.shape[0]):
                #i is all points in one dpr footprint
                #distancen for all i
                index = np.isin(ix[i,:],ix2[i] )
                res1 = np.nanmax(rwdata_cut.ravel()[ix[i,:][index]])
                ry_par.append(res1)
              
    elif calc=='min':

            for i in range(ix.shape[0]):
                #i is all points in one dpr footprint
                #distancen for all i
                index = np.isin(ix[i,:],ix2[i] )
                res1 = np.nanmin(rwdata_cut.ravel()[ix[i,:][index]])
                ry_par.append(res1) 
                
    else:
        print ('Wrong calc parameter declaration!')


    return np.array(ry_par)

# %%
def gpm_scan_time(filename, scanswath='NS'):
    from netCDF4 import Dataset
    pr_data = Dataset(filename, mode="r")
    year = pr_data['NS']['ScanTime'].variables['Year']
    month = pr_data['NS']['ScanTime'].variables['Month']
    dayofmonth = pr_data['NS']['ScanTime'].variables['DayOfMonth']
    # dayofyear = pr_data['NS']['ScanTime'].variables['DayOfYear'][mask]
    hour = pr_data['NS']['ScanTime'].variables['Hour']
    minute = pr_data['NS']['ScanTime'].variables['Minute']
    second = pr_data['NS']['ScanTime'].variables['Second']
    # secondofday = pr_data['NS']['ScanTime'].variables['SecondOfDay'][mask]
    millisecond = pr_data['NS']['ScanTime'].variables['MilliSecond']
    date_array = zip(year, month, dayofmonth,
                     hour, minute, second,
                     millisecond)
    pr_time = np.array(
        [dt.datetime(d[0], d[1], d[2], d[3], d[4], d[5], d[6]) for d in date_array])
    
    #ttt = gpm_scan_time(gpm_file)
    s_n = {'NS':49, 'HS':24, 'MS':25}
    
    time_array = np.array(s_n[scanswath] * [pr_time]).T
    
    return time_array

# %%
def get_time_of_gpm2(gpm_time):
    """einfache mittlere zeit"""
    iii = int(len(np.array(gpm_time['Year']))/2)
    gpm_year = np.array(gpm_time['Year'])[iii]
    gpm_month = np.array(gpm_time['Month'])[iii]
    gpm_day = np.array(gpm_time['DayOfMonth'])[iii]
    gpm_hour = np.array(gpm_time['Hour'])[iii]
    gpm_min = np.array(gpm_time['Minute'])[iii]
    gpm_sek = np.array(gpm_time['Second'])[iii]
    gpm_dt = dt.datetime(gpm_year,gpm_month, gpm_day, gpm_hour, gpm_min, gpm_sek).strftime("%Y.%m.%d -- %H:%M:%S")
    return gpm_dt

# %%
def write2hdf(name, x, y, sr_pns, sr_pes, sr_pav, sr_bbh, sr_bbw, sr_phase, sr_type, sr_sth,
             sr_cfb, sr_lst, sr_ele, sr_tim, gr_pp_ipoli, gr_xy, gr_pp, gr_h_max, gr_h_min, gr_h_mean, gr_h_std,
             sr_time, gr_time):
    """
    
    Write data in HDF5 file
    
    """
    hdat = h5py.File(str(name) + '.hdf5', 'w')
    
    ## Create Groups SR and GR estimates
    grp_sr = hdat.create_group("SR")
    grp_sr.attrs['description']=" space-borne estimates"
    grp_gr = hdat.create_group("GR")
    grp_gr.attrs['description']=" ground-based estimates"
    
    ## SR
    g_x=grp_sr.create_dataset('sr_x', data=x, compression="gzip")
    g_x.attrs['description'] = 'space-borne x-coordinates in km' 
    
    g_y = grp_sr.create_dataset('sr_y', data=y, compression="gzip")
    g_y.attrs['description'] = 'space-borne y-coordinates in km'
    
    g_sr_pns = grp_sr.create_dataset('sr_pns', data=sr_pns, compression="gzip")
    g_sr_pns.attrs['description'] = 'precip near surface (mm/h)'
    
    g_sr_pes = grp_sr.create_dataset('sr_pes', data=sr_pes, compression="gzip")
    g_sr_pes.attrs['description'] = 'precip estimated surface (mm/h)'
    
    g_sr_pav = grp_sr.create_dataset('sr_pav', data=sr_pav, compression="gzip")
    g_sr_pav.attrs['description'] = 'precip mean between 2 and 4 km (mm/h)'
    
    g_sr_bbh = grp_sr.create_dataset('sr_bbh', data=sr_bbh, compression="gzip")
    g_sr_bbh.attrs['description'] = 'bright band height (m)'
    
    g_sr_bbw = grp_sr.create_dataset('sr_bbw', data=sr_bbw, compression="gzip")
    g_sr_bbw.attrs['description'] = 'bright band width (m)'
    
    g_sr_pha = grp_sr.create_dataset('sr_phase', data=sr_phase, compression="gzip")
    g_sr_pha.attrs['description'] = 'hydrometeor phase near surface, 0=solid, 1=mixed, 2=liquid'
    
    g_sr_typ = grp_sr.create_dataset('sr_type', data=sr_type, compression="gzip")
    g_sr_typ.attrs['description'] = 'precip type, 1=strat, 2=conv, 3=other'
    
    g_sr_sth = grp_sr.create_dataset('sr_sth', data=sr_sth, compression="gzip")
    g_sr_sth.attrs['description'] = 'storm top hight (m)'
    
    g_sr_cfb = grp_sr.create_dataset('sr_cfb', data=sr_cfb, compression="gzip")
    g_sr_cfb.attrs['description'] = 'range bin number for clutter free bottom'
    
    g_sr_lst = grp_sr.create_dataset('sr_lst', data=sr_lst, compression="gzip")
    g_sr_lst.attrs['description'] = 'land surface type, O-99=Ocean, 100-199=Land,200-299=Coast, 300-399=InlandWater'
    
    g_sr_ele = grp_sr.create_dataset('sr_ele', data=sr_ele, compression="gzip")
    g_sr_ele.attrs['description'] = 'elevation of measurement point, Copy of DEMHmean (m)'
    
    g_sr_times = grp_sr.create_dataset('sr_times', data=sr_tim, compression="gzip")
    g_sr_times.attrs['description'] = 'scan times'
    
    ## GR
    g_gr_ipp = grp_gr.create_dataset('gr_pp_ipoli', data=gr_pp_ipoli, compression="gzip")
    g_gr_ipp.attrs['description'] = 'ground precip ipol on sr grid'
    g_gr_xyc = grp_gr.create_dataset('gr_xy', data=gr_xy, compression="gzip")
    g_gr_xyc.attrs['description'] = 'ground based xy coordinates (km)'
    g_gr_npp = grp_gr.create_dataset('gr_pp', data=gr_pp, compression="gzip")
    g_gr_npp.attrs['description'] = 'ground precip on gr grid'
    g_gr_hmax = grp_gr.create_dataset('gr_h_max', data=gr_h_max, compression="gzip")
    g_gr_hmax.attrs['description'] = 'max measured height over ground on sr grid (m)'
    g_gr_hmin = grp_gr.create_dataset('gr_h_min', data=gr_h_min, compression="gzip")
    g_gr_hmin.attrs['description'] = 'min measured height over ground on sr grid (m)'
    g_gr_hmea = grp_gr.create_dataset('gr_h_mean', data=gr_h_mean, compression="gzip")
    g_gr_hmea.attrs['description'] = 'mean measured height over ground on sr grid (m)'
    g_gr_hstd = grp_gr.create_dataset('gr_h_std', data=gr_h_std, compression="gzip")
    g_gr_hstd.attrs['description'] = 'std measured height over ground on sr grid (m)'
    
    # Times
    g_sr_otime = grp_sr.create_dataset('sr_time', data=sr_time)
    g_sr_otime.attrs['description'] = 'SR Overpass time'
    g_gr_otime = grp_gr.create_dataset('gr_time', data=gr_time)
    g_gr_otime.attrs['description'] = 'GR Meassured time'

    hdat.close()

# %% [markdown]
# ### Import other parameters

# %%
# %%time

# Import radolan grid src
radolan_xy = wradlib.georef.get_radolan_grid(900,900)
radolan_xy = radolan_xy.reshape(-1, radolan_xy.shape[-1])
zd = wradlib.zonalstats.DataSource(radolan_xy, name='src')


# Determine projection
proj_stereo = wradlib.georef.create_osr("dwd-radolan")
proj_wgs = osr.SpatialReference()
proj_wgs.ImportFromEPSG(4326)

# Import RADOLAN Heights
rhmax = np.load("/automount/ags/velibor/data/radolan_dx/RADOLAN_H_xymax_900x900_dem1x1.npy")[2]
rhmin = np.load("/automount/ags/velibor/data/radolan_dx/RADOLAN_H_xymin_900x900_dem1x1.npy")[2]
rhmean = np.load("/automount/ags/velibor/data/radolan_dx/RADOLAN_H_xymean_900x900_dem1x1.npy")[2]
rhstd = np.load("/automount/ags/velibor/data/radolan_dx/RADOLAN_H_xystd_900x900.npy")[2]


# Other Parameters
# dpr_footprint
# dpr swath NS MS HS
# Scan swath
sc = 'NS'
# Out:
# CPU times: user 19.7 s, sys: 366 ms, total: 20.1 s
# Wall time: 20.7 s

# %%
# %%time
gpm_dir =sorted(glob.glob('/automount/ags/velibor/gpmdata/dprV7_small/*radolan.GPM*.HDF5'))

for gpm_file in gpm_dir[300:-1]:
    # read gpm file with importatnt parameters
    gpmdpr = h5py.File(gpm_file, 'r')

    # gpm scantimes
    gpm_scan_times = gpm_scan_time(gpm_file, scanswath=sc)

    # GPM navigation and time
    gpm_lat = np.array(gpmdpr[sc]['Latitude'])
    gpm_lon = np.array(gpmdpr[sc]['Longitude'])
    gpm_time = gpmdpr[sc]['ScanTime']


    try:
        #gpm_zeit = get_time_of_gpm(gpm_lon, gpm_lat, gpm_time)
        gpm_zeit = get_time_of_gpm2(gpm_time)

    except ValueError:
        pass
        print ('____________ValueError____________')
    else:
        #gpm_zeit = get_time_of_gpm(gpm_lon, gpm_lat, gpm_time)
        print gpm_zeit
        ht, mt = gpm_zeit[14:16], str(int(round(float(gpm_zeit[17:19])/5.0)*5.0))
        year, ye, m, d = gpm_zeit[0:4], gpm_zeit[2:4], gpm_zeit[5:7], gpm_zeit[8:10]

        if mt == '0':
            mt = '00'
        if mt == '5':
            mt = '05'
        if mt == '60':
            mt = '55'
            ht = str(int(ht)+1)
            if ht == '24':
                d = str(int(d)+1)

        print gpm_zeit

        r_pro = 'ry'
        #try:


        r_pfad = ('/automount/radar/dwd/'+ r_pro +'/'+str(year)+'/'+str(year)+'-'+
                str(m)+'/'+ str(year)+'-'+str(m)+'-'+str(d)+'/raa01-'+r_pro+'_10000-'+
                str(ye)+str(m)+ str(d)+str(ht)+str(mt)+'-dwd---bi*')
        print r_pfad


        ## TRY: gibt es eine RADOLAN Datei zum Overpass!?
        # read radolan ry file data and attributes
        try:
            rwdata, rwattrs = wradlib.io.read_radolan_composite(glob.glob(r_pfad)[0])

            radolan_grid_xy = wradlib.georef.get_radolan_grid(900,900)
            x = radolan_grid_xy[:,:,0]
            y = radolan_grid_xy[:,:,1]
            rwdata = np.ma.masked_equal(rwdata, -9999) *12 # Um auf mm/h zu kommen, beim Einlesen sind es mm/5min

            radolan_scan_time = rwattrs['datetime']

            # copy data for binary grid
            bingrid = rwdata.copy()

            # Precipitation data in RADOLAN region
            # Posible products:
            # precipRateAve24
            # precipRateESurface
            # precipRateNearSurface
            dpr_pns = np.array(gpmdpr[sc]['SLV']['precipRateNearSurface'])
            dpr_pns[dpr_pns ==-9999.9]= np.nan

            dpr_pes = np.array(gpmdpr[sc]['SLV']['precipRateESurface'])
            dpr_pes[dpr_pes ==-9999.9]= np.nan

            dpr_pav = np.array(gpmdpr[sc]['SLV']['precipRateAve24'])
            dpr_pav[dpr_pav ==-9999.9]= np.nan

            # Brightband height
            dpr_bbh = np.array(gpmdpr[sc]['CSF']['heightBB'], dtype=float)
            dpr_bbh[dpr_bbh ==-9999.9] = np.nan

            # Bright-band width
            dpr_bbw = np.array(gpmdpr[sc]['CSF']['widthBB'], dtype=float)
            dpr_bbw[dpr_bbw ==-9999.9] = np.nan

            # PhaseNearSurface
            dpr_pha = np.array(gpmdpr[sc]['SLV']['phaseNearSurface'], dtype=int)
            #dpr_pha = dpr_pha/100
            #dpr_phase[dpr_phase==255]=np.nan

            #typePrecip
            dpr_typ = np.array(gpmdpr[sc]['CSF']['typePrecip'], dtype=float)

            #StromTopHeight
            dpr_sth = np.array(gpmdpr[sc]['PRE']['heightStormTop'], dtype=float)
            dpr_sth[dpr_sth ==-9999.9] = np.nan

            #Elevation
            dpr_ele = np.array(gpmdpr[sc]['PRE']['elevation'], dtype=float)
            dpr_ele[dpr_ele == -9999] = np.nan

            #Clutterfreebottom
            dpr_cfb = np.array(gpmdpr[sc]['PRE']['binClutterFreeBottom'], dtype=float)
            dpr_cfb[dpr_cfb==-9999]
            ###################################### Hier den Richtigen Clutterfreebottom berechnen!!!
            ###################################### Funktion auf dem Laptop
            
            # Landsurfacetyp
            dpr_lst = np.array(gpmdpr[sc]['PRE']['landSurfaceType'])
            dpr_lst[dpr_lst==-9999]

            # PiaFinal
            #dpr_pia = np.array(gpmdpr[sc]['SLV']['piaFinal'], dtype=float)
            #dpr_pia[dpr_pia == -9999] = np.nan
            
            # flagHeavyIcePrecip FLAG!
            # dpr_ice = np.array(gpmdpr[sc]['PRE']['flagHeavyIcePrecip'], dtype=float)
            # dpr_ice[dpr_ice == -99] = np.nan
            



            # GPM coordinate projection
            gpm_x, gpm_y = wradlib.georef.reproject(gpm_lon, gpm_lat,
                                                    projection_target=proj_stereo,
                                                    projection_source=proj_wgs)


            ## Remove all GPM footprint that are not in scan area of radolan
            ## -------------------------------------------------------------

            # GPM Koordinaten ravel
            gpm_xy = np.vstack((gpm_x.ravel(), gpm_y.ravel())).transpose()

            # index for GPM footprints in scan area
            oi_idx = idx_sr_in_gr_area(bingrid, gpm_xy)

            # entferne alle Indizes auserhalb des äußeren Polygons
            gpm_xy = gpm_xy[oi_idx]
            gpm_pns = dpr_pns.ravel()[oi_idx]
            gpm_pes = dpr_pes.ravel()[oi_idx]
            gpm_pav = dpr_pav.ravel()[oi_idx]
            gpm_bbh = dpr_bbh.ravel()[oi_idx]
            gpm_bbw = dpr_bbw.ravel()[oi_idx]
            gpm_pha = dpr_pha.ravel()[oi_idx]
            gpm_typ = dpr_typ.ravel()[oi_idx]
            gpm_sth = dpr_sth.ravel()[oi_idx]
            gpm_ele = dpr_ele.ravel()[oi_idx]
            gpm_cfb = dpr_cfb.ravel()[oi_idx]
            gpm_lst = dpr_lst.ravel()[oi_idx]
            gpm_tim = gpm_scan_times.ravel()[oi_idx]


            ## Remove all RADOLAN Points not included in GPM DPR swath
            ## -------------------------------------------------------

            # Contour from ORIGINAL DPR Overpass
            dpr_contour_x = dpr_swath_contour(gpm_x)
            dpr_contour_y = dpr_swath_contour(gpm_y)
            print(dpr_contour_x.shape)

            # create dpr polygon of dpr xy contours 
            dpr_xy_poly = np.vstack((dpr_contour_x.ravel(), dpr_contour_y.ravel())).transpose()

            #load regular radolan grid and overlie with dpr contours
            zd_poly_radolan = wradlib.zonalstats.ZonalDataPoint(zd, [dpr_xy_poly], buf=2.5)

            # get radolan index in dpr swath
            ry_idx = zd_poly_radolan.get_source_index(0)

            # get radolan index in dpr swath AND in binary grid
            rwtest = ~np.ma.masked_less(rwdata, 0).mask

            radolan_idx = np.flatnonzero(rwtest.ravel())

            ry_idx2 = np.intersect1d(ry_idx, radolan_idx, assume_unique=True)

            # Radolan xy array
            xy_radolan = np.vstack((x.ravel(), y.ravel())).transpose()

            # Extract all affected RADOLAN grid points
            rwdata_cut = rwdata.ravel()[ry_idx2]
            x_cut = xy_radolan[...,0].ravel()[ry_idx2].copy()
            y_cut = xy_radolan[...,1].ravel()[ry_idx2].copy()


            # extrect all Height points (need to have the same shape as radolan grid)
            radolan_height_min_cut = rhmin.ravel()[ry_idx2]
            radolan_height_max_cut = rhmax.ravel()[ry_idx2]
            radolan_height_mean_cut = rhmean.ravel()[ry_idx2]
            radolan_height_std_cut = rhstd.ravel()[ry_idx2]


            # Compare all cutted radolan x and y 
            xy_cut = np.vstack((x_cut.ravel(), y_cut.ravel())).transpose()

            #Dpr footprint radius 
            dpr_footprint = 2.6 #radius in km

            # Interpolation with antena weighted function
            ry_pns_w = ipoli_radi_w(xy_cut, gpm_xy, rwdata_cut, dpr_footprint, k=25)

            # Interpolation of other parameters on dpr grid
            radolan_height_min_cut_ipoli = ipoli_radi(xy_cut, gpm_xy, radolan_height_min_cut, dpr_footprint, k=25, calc='min')
            radolan_height_max_cut_ipoli = ipoli_radi(xy_cut, gpm_xy, radolan_height_max_cut, dpr_footprint, k=25, calc='max')
            radolan_height_mean_cut_ipoli = ipoli_radi(xy_cut, gpm_xy, radolan_height_mean_cut, dpr_footprint, k=25)
            radolan_height_std_cut_ipoli = ipoli_radi(xy_cut, gpm_xy, radolan_height_std_cut, dpr_footprint, k=25)


            ## Write and save to HDF5 file
            ## ----------------------------
            name = '/automount/ags/velibor/gpmdata/dumpdataV7/' \
                               'dpr_ry_'+sc+'/dprrado_'+ sc + str(gpm_zeit)

            # array with datetime in array with datimestrings
            gpm_tim_str = [dt.datetime.strftime(date, "%Y-%m-%d %H:%M:%S") for date in gpm_tim]    

            write2hdf(name, gpm_xy[:,0], gpm_xy[:,1],
                      gpm_pns, gpm_pes, gpm_pav,
                      gpm_bbh, gpm_bbw, gpm_pha,
                      gpm_typ, gpm_sth, gpm_cfb,
                      gpm_lst, gpm_ele, gpm_tim_str,
                      ry_pns_w, xy_cut, rwdata_cut,
                      radolan_height_max_cut_ipoli,
                      radolan_height_min_cut_ipoli, 
                      radolan_height_mean_cut_ipoli,
                      radolan_height_std_cut_ipoli,
                      gpm_zeit,
                      dt.datetime.strftime(radolan_scan_time, "%Y-%m-%d %H:%M:%S"))
        except:
            print('__________________________________________RY File Missing!')
            #np.save('/automount/ags/velibor/gpmdata/dumpdataV7/'+gpm_zeit,[0])
# Out:
# 2017.07.10 -- 02:14:45
# 2017.07.10 -- 02:14:45
# /automount/radar/dwd/ry/2017/2017-07/2017-07-10/raa01-ry_10000-1707100215-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.10 -- 03:50:25
# 2017.07.10 -- 03:50:25
# /automount/radar/dwd/ry/2017/2017-07/2017-07-10/raa01-ry_10000-1707100350-dwd---bi*
# not relevant polygon removed
# (353,)
# 2017.07.10 -- 18:57:41
# 2017.07.10 -- 18:57:41
# /automount/radar/dwd/ry/2017/2017-07/2017-07-10/raa01-ry_10000-1707101855-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.10 -- 20:33:24
# 2017.07.10 -- 20:33:24
# /automount/radar/dwd/ry/2017/2017-07/2017-07-10/raa01-ry_10000-1707102035-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.11 -- 02:58:10
# 2017.07.11 -- 02:58:10
# /automount/radar/dwd/ry/2017/2017-07/2017-07-11/raa01-ry_10000-170711355-dwd---bi*
# __________________________________________RY File Missing!
# 2017.07.11 -- 19:41:04
# 2017.07.11 -- 19:41:04
# /automount/radar/dwd/ry/2017/2017-07/2017-07-11/raa01-ry_10000-1707111940-dwd---bi*
# not relevant polygon removed
# (599,)
# 2017.07.12 -- 02:05:40
# 2017.07.12 -- 02:05:40
# /automount/radar/dwd/ry/2017/2017-07/2017-07-12/raa01-ry_10000-1707120205-dwd---bi*
# not relevant polygon removed
# (425,)
# 2017.07.12 -- 18:48:43
# 2017.07.12 -- 18:48:43
# /automount/radar/dwd/ry/2017/2017-07/2017-07-12/raa01-ry_10000-1707121850-dwd---bi*
# not relevant polygon removed
# (539,)
# 2017.07.13 -- 01:13:32
# 2017.07.13 -- 01:13:32
# /automount/radar/dwd/ry/2017/2017-07/2017-07-13/raa01-ry_10000-1707130115-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.13 -- 02:49:07
# 2017.07.13 -- 02:49:07
# /automount/radar/dwd/ry/2017/2017-07/2017-07-13/raa01-ry_10000-1707130250-dwd---bi*
# not relevant polygon removed
# (457,)
# 2017.07.13 -- 17:56:20
# 2017.07.13 -- 17:56:20
# /automount/radar/dwd/ry/2017/2017-07/2017-07-13/raa01-ry_10000-1707131755-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.13 -- 19:32:08
# 2017.07.13 -- 19:32:08
# /automount/radar/dwd/ry/2017/2017-07/2017-07-13/raa01-ry_10000-1707131930-dwd---bi*
# not relevant polygon removed
# (341,)
# 2017.07.14 -- 01:56:53
# 2017.07.14 -- 01:56:53
# /automount/radar/dwd/ry/2017/2017-07/2017-07-14/raa01-ry_10000-1707140155-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.07.14 -- 18:39:38
# 2017.07.14 -- 18:39:38
# /automount/radar/dwd/ry/2017/2017-07/2017-07-14/raa01-ry_10000-1707141840-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.07.15 -- 01:04:22
# 2017.07.15 -- 01:04:22
# /automount/radar/dwd/ry/2017/2017-07/2017-07-15/raa01-ry_10000-1707150105-dwd---bi*
# not relevant polygon removed
# (333,)
# 2017.07.15 -- 02:40:12
# 2017.07.15 -- 02:40:12
# /automount/radar/dwd/ry/2017/2017-07/2017-07-15/raa01-ry_10000-1707150240-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.15 -- 17:47:24
# 2017.07.15 -- 17:47:24
# /automount/radar/dwd/ry/2017/2017-07/2017-07-15/raa01-ry_10000-1707151745-dwd---bi*
# not relevant polygon removed
# (443,)
# 2017.07.15 -- 19:22:59
# 2017.07.15 -- 19:22:59
# /automount/radar/dwd/ry/2017/2017-07/2017-07-15/raa01-ry_10000-1707151920-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.16 -- 01:47:49
# 2017.07.16 -- 01:47:49
# /automount/radar/dwd/ry/2017/2017-07/2017-07-16/raa01-ry_10000-1707160145-dwd---bi*
# not relevant polygon removed
# (551,)
# 2017.07.16 -- 18:30:49
# 2017.07.16 -- 18:30:49
# /automount/radar/dwd/ry/2017/2017-07/2017-07-16/raa01-ry_10000-1707161830-dwd---bi*
# not relevant polygon removed
# (437,)
# 2017.07.17 -- 00:55:24
# 2017.07.17 -- 00:55:24
# /automount/radar/dwd/ry/2017/2017-07/2017-07-17/raa01-ry_10000-1707170055-dwd---bi*
# not relevant polygon removed
# (591,)
# 2017.07.17 -- 17:38:20
# 2017.07.17 -- 17:38:20
# /automount/radar/dwd/ry/2017/2017-07/2017-07-17/raa01-ry_10000-1707171740-dwd---bi*
# not relevant polygon removed
# (661,)
# 2017.07.18 -- 00:03:03
# 2017.07.18 -- 00:03:03
# /automount/radar/dwd/ry/2017/2017-07/2017-07-18/raa01-ry_10000-1707180005-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.18 -- 01:38:47
# 2017.07.18 -- 01:38:47
# /automount/radar/dwd/ry/2017/2017-07/2017-07-18/raa01-ry_10000-1707180140-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.18 -- 16:46:02
# 2017.07.18 -- 16:46:02
# /automount/radar/dwd/ry/2017/2017-07/2017-07-18/raa01-ry_10000-1707181645-dwd---bi*
# not relevant polygon removed
# (339,)
# 2017.07.18 -- 18:21:40
# 2017.07.18 -- 18:21:40
# /automount/radar/dwd/ry/2017/2017-07/2017-07-18/raa01-ry_10000-1707181820-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.19 -- 00:46:29
# 2017.07.19 -- 00:46:29
# /automount/radar/dwd/ry/2017/2017-07/2017-07-19/raa01-ry_10000-1707190045-dwd---bi*
# not relevant polygon removed
# (641,)
# 2017.07.19 -- 17:29:25
# 2017.07.19 -- 17:29:25
# /automount/radar/dwd/ry/2017/2017-07/2017-07-19/raa01-ry_10000-1707191730-dwd---bi*
# not relevant polygon removed
# (541,)
# 2017.07.19 -- 23:53:56
# 2017.07.19 -- 23:53:56
# /automount/radar/dwd/ry/2017/2017-07/2017-07-19/raa01-ry_10000-1707192355-dwd---bi*
# not relevant polygon removed
# (499,)
# 2017.07.20 -- 16:36:55
# 2017.07.20 -- 16:36:55
# /automount/radar/dwd/ry/2017/2017-07/2017-07-20/raa01-ry_10000-1707201635-dwd---bi*
# not relevant polygon removed
# (605,)
# 2017.07.20 -- 23:01:42
# 2017.07.20 -- 23:01:42
# /automount/radar/dwd/ry/2017/2017-07/2017-07-20/raa01-ry_10000-1707202300-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.21 -- 00:37:20
# 2017.07.21 -- 00:37:20
# /automount/radar/dwd/ry/2017/2017-07/2017-07-21/raa01-ry_10000-1707210035-dwd---bi*
# not relevant polygon removed
# (381,)
# 2017.07.21 -- 15:44:33
# 2017.07.21 -- 15:44:33
# /automount/radar/dwd/ry/2017/2017-07/2017-07-21/raa01-ry_10000-1707211545-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.21 -- 17:20:18
# 2017.07.21 -- 17:20:18
# /automount/radar/dwd/ry/2017/2017-07/2017-07-21/raa01-ry_10000-1707211720-dwd---bi*
# not relevant polygon removed
# (277,)
# 2017.07.21 -- 23:45:02
# 2017.07.21 -- 23:45:02
# /automount/radar/dwd/ry/2017/2017-07/2017-07-21/raa01-ry_10000-1707212345-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.07.22 -- 16:27:51
# 2017.07.22 -- 16:27:51
# /automount/radar/dwd/ry/2017/2017-07/2017-07-22/raa01-ry_10000-1707221625-dwd---bi*
# not relevant polygon removed
# (619,)
# 2017.07.22 -- 22:52:30
# 2017.07.22 -- 22:52:30
# /automount/radar/dwd/ry/2017/2017-07/2017-07-22/raa01-ry_10000-1707222250-dwd---bi*
# not relevant polygon removed
# (399,)
# 2017.07.23 -- 15:35:29
# 2017.07.23 -- 15:35:29
# /automount/radar/dwd/ry/2017/2017-07/2017-07-23/raa01-ry_10000-1707231535-dwd---bi*
# not relevant polygon removed
# (513,)
# 2017.07.23 -- 23:35:53
# 2017.07.23 -- 23:35:53
# /automount/radar/dwd/ry/2017/2017-07/2017-07-23/raa01-ry_10000-1707232335-dwd---bi*
# not relevant polygon removed
# (483,)
# 2017.07.24 -- 14:43:01
# 2017.07.24 -- 14:43:01
# /automount/radar/dwd/ry/2017/2017-07/2017-07-24/raa01-ry_10000-1707241445-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.24 -- 16:18:51
# 2017.07.24 -- 16:18:51
# /automount/radar/dwd/ry/2017/2017-07/2017-07-24/raa01-ry_10000-1707241620-dwd---bi*
# not relevant polygon removed
# (369,)
# 2017.07.24 -- 22:43:33
# 2017.07.24 -- 22:43:33
# /automount/radar/dwd/ry/2017/2017-07/2017-07-24/raa01-ry_10000-1707242245-dwd---bi*
# not relevant polygon removed
# (641,)
# 2017.07.25 -- 15:26:18
# 2017.07.25 -- 15:26:18
# /automount/radar/dwd/ry/2017/2017-07/2017-07-25/raa01-ry_10000-1707251525-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.07.25 -- 21:51:01
# 2017.07.25 -- 21:51:01
# /automount/radar/dwd/ry/2017/2017-07/2017-07-25/raa01-ry_10000-1707252150-dwd---bi*
# not relevant polygon removed
# (305,)
# 2017.07.25 -- 23:26:49
# 2017.07.25 -- 23:26:49
# /automount/radar/dwd/ry/2017/2017-07/2017-07-25/raa01-ry_10000-1707252325-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.26 -- 14:33:59
# 2017.07.26 -- 14:33:59
# /automount/radar/dwd/ry/2017/2017-07/2017-07-26/raa01-ry_10000-1707261435-dwd---bi*
# not relevant polygon removed
# (413,)
# 2017.07.26 -- 16:09:35
# 2017.07.26 -- 16:09:35
# /automount/radar/dwd/ry/2017/2017-07/2017-07-26/raa01-ry_10000-1707261610-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.26 -- 22:34:24
# 2017.07.26 -- 22:34:24
# /automount/radar/dwd/ry/2017/2017-07/2017-07-26/raa01-ry_10000-1707262235-dwd---bi*
# not relevant polygon removed
# (579,)
# 2017.07.27 -- 15:17:20
# 2017.07.27 -- 15:17:20
# /automount/radar/dwd/ry/2017/2017-07/2017-07-27/raa01-ry_10000-1707271515-dwd---bi*
# not relevant polygon removed
# (469,)
# 2017.07.27 -- 21:41:51
# 2017.07.27 -- 21:41:51
# /automount/radar/dwd/ry/2017/2017-07/2017-07-27/raa01-ry_10000-1707272140-dwd---bi*
# not relevant polygon removed
# (573,)
# 2017.07.28 -- 14:24:47
# 2017.07.28 -- 14:24:47
# /automount/radar/dwd/ry/2017/2017-07/2017-07-28/raa01-ry_10000-1707281425-dwd---bi*
# not relevant polygon removed
# (655,)
# 2017.07.28 -- 20:49:31
# 2017.07.28 -- 20:49:31
# /automount/radar/dwd/ry/2017/2017-07/2017-07-28/raa01-ry_10000-1707282050-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.28 -- 22:25:13
# 2017.07.28 -- 22:25:13
# /automount/radar/dwd/ry/2017/2017-07/2017-07-28/raa01-ry_10000-1707282225-dwd---bi*
# not relevant polygon removed
# (307,)
# 2017.07.29 -- 13:32:25
# 2017.07.29 -- 13:32:25
# /automount/radar/dwd/ry/2017/2017-07/2017-07-29/raa01-ry_10000-1707291330-dwd---bi*
# not relevant polygon removed
# (303,)
# 2017.07.29 -- 15:08:05
# 2017.07.29 -- 15:08:05
# /automount/radar/dwd/ry/2017/2017-07/2017-07-29/raa01-ry_10000-1707291510-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.29 -- 21:32:50
# 2017.07.29 -- 21:32:50
# /automount/radar/dwd/ry/2017/2017-07/2017-07-29/raa01-ry_10000-1707292130-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.07.30 -- 14:15:45
# 2017.07.30 -- 14:15:45
# /automount/radar/dwd/ry/2017/2017-07/2017-07-30/raa01-ry_10000-1707301415-dwd---bi*
# not relevant polygon removed
# (573,)
# 2017.07.30 -- 20:40:15
# 2017.07.30 -- 20:40:15
# /automount/radar/dwd/ry/2017/2017-07/2017-07-30/raa01-ry_10000-1707302040-dwd---bi*
# not relevant polygon removed
# (467,)
# 2017.07.31 -- 13:23:12
# 2017.07.31 -- 13:23:12
# /automount/radar/dwd/ry/2017/2017-07/2017-07-31/raa01-ry_10000-1707311325-dwd---bi*
# not relevant polygon removed
# (577,)
# 2017.07.31 -- 19:47:59
# 2017.07.31 -- 19:47:59
# /automount/radar/dwd/ry/2017/2017-07/2017-07-31/raa01-ry_10000-1707311945-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.07.31 -- 21:23:36
# 2017.07.31 -- 21:23:36
# /automount/radar/dwd/ry/2017/2017-07/2017-07-31/raa01-ry_10000-1707312125-dwd---bi*
# not relevant polygon removed
# (415,)
# 2017.08.01 -- 12:30:46
# 2017.08.01 -- 12:30:46
# /automount/radar/dwd/ry/2017/2017-08/2017-08-01/raa01-ry_10000-1708011230-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.01 -- 14:06:31
# 2017.08.01 -- 14:06:31
# /automount/radar/dwd/ry/2017/2017-08/2017-08-01/raa01-ry_10000-1708011405-dwd---bi*
# not relevant polygon removed
# (305,)
# 2017.08.01 -- 20:31:15
# 2017.08.01 -- 20:31:15
# /automount/radar/dwd/ry/2017/2017-08/2017-08-01/raa01-ry_10000-1708012030-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.08.02 -- 13:13:57
# 2017.08.02 -- 13:13:57
# /automount/radar/dwd/ry/2017/2017-08/2017-08-02/raa01-ry_10000-1708021315-dwd---bi*
# not relevant polygon removed
# (643,)
# 2017.08.02 -- 19:38:38
# 2017.08.02 -- 19:38:38
# /automount/radar/dwd/ry/2017/2017-08/2017-08-02/raa01-ry_10000-1708021940-dwd---bi*
# not relevant polygon removed
# (367,)
# 2017.08.02 -- 21:14:28
# 2017.08.02 -- 21:14:28
# /automount/radar/dwd/ry/2017/2017-08/2017-08-02/raa01-ry_10000-1708022115-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.03 -- 12:21:34
# 2017.08.03 -- 12:21:34
# /automount/radar/dwd/ry/2017/2017-08/2017-08-03/raa01-ry_10000-1708031220-dwd---bi*
# not relevant polygon removed
# (479,)
# 2017.08.03 -- 20:21:57
# 2017.08.03 -- 20:21:57
# /automount/radar/dwd/ry/2017/2017-08/2017-08-03/raa01-ry_10000-1708032020-dwd---bi*
# not relevant polygon removed
# (517,)
# 2017.08.04 -- 13:04:54
# 2017.08.04 -- 13:04:54
# /automount/radar/dwd/ry/2017/2017-08/2017-08-04/raa01-ry_10000-1708041305-dwd---bi*
# not relevant polygon removed
# (401,)
# 2017.08.04 -- 19:29:30
# 2017.08.04 -- 19:29:30
# /automount/radar/dwd/ry/2017/2017-08/2017-08-04/raa01-ry_10000-1708041930-dwd---bi*
# not relevant polygon removed
# (619,)
# 2017.08.05 -- 12:12:16
# 2017.08.05 -- 12:12:16
# /automount/radar/dwd/ry/2017/2017-08/2017-08-05/raa01-ry_10000-1708051210-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.08.05 -- 18:36:59
# 2017.08.05 -- 18:36:59
# /automount/radar/dwd/ry/2017/2017-08/2017-08-05/raa01-ry_10000-1708051835-dwd---bi*
# not relevant polygon removed
# (273,)
# 2017.08.05 -- 20:12:43
# 2017.08.05 -- 20:12:43
# /automount/radar/dwd/ry/2017/2017-08/2017-08-05/raa01-ry_10000-1708052010-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.06 -- 11:19:53
# 2017.08.06 -- 11:19:53
# /automount/radar/dwd/ry/2017/2017-08/2017-08-06/raa01-ry_10000-1708061120-dwd---bi*
# not relevant polygon removed
# (375,)
# 2017.08.06 -- 12:55:30
# 2017.08.06 -- 12:55:30
# /automount/radar/dwd/ry/2017/2017-08/2017-08-06/raa01-ry_10000-1708061255-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.06 -- 19:20:16
# 2017.08.06 -- 19:20:16
# /automount/radar/dwd/ry/2017/2017-08/2017-08-06/raa01-ry_10000-1708061920-dwd---bi*
# not relevant polygon removed
# (611,)
# 2017.08.07 -- 12:03:10
# 2017.08.07 -- 12:03:10
# /automount/radar/dwd/ry/2017/2017-08/2017-08-07/raa01-ry_10000-1708071205-dwd---bi*
# not relevant polygon removed
# (507,)
# 2017.08.07 -- 18:27:39
# 2017.08.07 -- 18:27:39
# /automount/radar/dwd/ry/2017/2017-08/2017-08-07/raa01-ry_10000-1708071825-dwd---bi*
# not relevant polygon removed
# (535,)
# 2017.08.08 -- 11:10:31
# 2017.08.08 -- 11:10:31
# /automount/radar/dwd/ry/2017/2017-08/2017-08-08/raa01-ry_10000-1708081110-dwd---bi*
# not relevant polygon removed
# (631,)
# 2017.08.08 -- 17:35:17
# 2017.08.08 -- 17:35:17
# /automount/radar/dwd/ry/2017/2017-08/2017-08-08/raa01-ry_10000-1708081735-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.08 -- 19:10:55
# 2017.08.08 -- 19:10:55
# /automount/radar/dwd/ry/2017/2017-08/2017-08-08/raa01-ry_10000-1708081910-dwd---bi*
# not relevant polygon removed
# (349,)
# 2017.08.09 -- 10:18:04
# 2017.08.09 -- 10:18:04
# /automount/radar/dwd/ry/2017/2017-08/2017-08-09/raa01-ry_10000-1708091020-dwd---bi*
# __________________________________________RY File Missing!
# 2017.08.09 -- 11:53:48
# 2017.08.09 -- 11:53:48
# /automount/radar/dwd/ry/2017/2017-08/2017-08-09/raa01-ry_10000-1708091155-dwd---bi*
# __________________________________________RY File Missing!
# 2017.08.09 -- 18:18:27
# 2017.08.09 -- 18:18:27
# /automount/radar/dwd/ry/2017/2017-08/2017-08-09/raa01-ry_10000-1708091820-dwd---bi*
# not relevant polygon removed
# (661,)
# 2017.08.10 -- 11:01:01
# 2017.08.10 -- 11:01:01
# /automount/radar/dwd/ry/2017/2017-08/2017-08-10/raa01-ry_10000-1708101100-dwd---bi*
# not relevant polygon removed
# (601,)
# 2017.08.10 -- 17:25:29
# 2017.08.10 -- 17:25:29
# /automount/radar/dwd/ry/2017/2017-08/2017-08-10/raa01-ry_10000-1708101725-dwd---bi*
# not relevant polygon removed
# (423,)
# 2017.08.11 -- 10:08:08
# 2017.08.11 -- 10:08:08
# /automount/radar/dwd/ry/2017/2017-08/2017-08-11/raa01-ry_10000-1708111010-dwd---bi*
# not relevant polygon removed
# (533,)
# 2017.08.11 -- 18:08:24
# 2017.08.11 -- 18:08:24
# /automount/radar/dwd/ry/2017/2017-08/2017-08-11/raa01-ry_10000-1708111810-dwd---bi*
# not relevant polygon removed
# (463,)
# 2017.08.12 -- 09:15:16
# 2017.08.12 -- 09:15:16
# /automount/radar/dwd/ry/2017/2017-08/2017-08-12/raa01-ry_10000-1708120915-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.12 -- 10:51:04
# 2017.08.12 -- 10:51:04
# /automount/radar/dwd/ry/2017/2017-08/2017-08-12/raa01-ry_10000-1708121050-dwd---bi*
# not relevant polygon removed
# (353,)
# 2017.08.12 -- 17:15:40
# 2017.08.12 -- 17:15:40
# /automount/radar/dwd/ry/2017/2017-08/2017-08-12/raa01-ry_10000-1708121715-dwd---bi*
# not relevant polygon removed
# (653,)
# 2017.08.13 -- 09:58:03
# 2017.08.13 -- 09:58:03
# /automount/radar/dwd/ry/2017/2017-08/2017-08-13/raa01-ry_10000-1708131055-dwd---bi*
# (657,)
# 2017.08.13 -- 16:22:41
# 2017.08.13 -- 16:22:41
# /automount/radar/dwd/ry/2017/2017-08/2017-08-13/raa01-ry_10000-1708131620-dwd---bi*
# not relevant polygon removed
# (315,)
# 2017.08.13 -- 17:58:25
# 2017.08.13 -- 17:58:25
# /automount/radar/dwd/ry/2017/2017-08/2017-08-13/raa01-ry_10000-1708131855-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.14 -- 09:05:19
# 2017.08.14 -- 09:05:19
# /automount/radar/dwd/ry/2017/2017-08/2017-08-14/raa01-ry_10000-1708140905-dwd---bi*
# not relevant polygon removed
# (421,)
# 2017.08.14 -- 10:40:54
# 2017.08.14 -- 10:40:54
# /automount/radar/dwd/ry/2017/2017-08/2017-08-14/raa01-ry_10000-1708141040-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.14 -- 17:05:34
# 2017.08.14 -- 17:05:34
# /automount/radar/dwd/ry/2017/2017-08/2017-08-14/raa01-ry_10000-1708141705-dwd---bi*
# not relevant polygon removed
# (573,)
# 2017.08.15 -- 09:48:13
# 2017.08.15 -- 09:48:13
# /automount/radar/dwd/ry/2017/2017-08/2017-08-15/raa01-ry_10000-1708150950-dwd---bi*
# not relevant polygon removed
# (465,)
# 2017.08.15 -- 16:12:37
# 2017.08.15 -- 16:12:37
# /automount/radar/dwd/ry/2017/2017-08/2017-08-15/raa01-ry_10000-1708151610-dwd---bi*
# not relevant polygon removed
# (573,)
# 2017.08.16 -- 08:55:13
# 2017.08.16 -- 08:55:13
# /automount/radar/dwd/ry/2017/2017-08/2017-08-16/raa01-ry_10000-1708160855-dwd---bi*
# not relevant polygon removed
# (653,)
# 2017.08.16 -- 15:19:51
# 2017.08.16 -- 15:19:51
# /automount/radar/dwd/ry/2017/2017-08/2017-08-16/raa01-ry_10000-1708161520-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.16 -- 16:55:29
# 2017.08.16 -- 16:55:29
# /automount/radar/dwd/ry/2017/2017-08/2017-08-16/raa01-ry_10000-1708161655-dwd---bi*
# not relevant polygon removed
# (309,)
# 2017.08.17 -- 08:02:25
# 2017.08.17 -- 08:02:25
# /automount/radar/dwd/ry/2017/2017-08/2017-08-17/raa01-ry_10000-1708170800-dwd---bi*
# (297,)
# 2017.08.17 -- 09:38:05
# 2017.08.17 -- 09:38:05
# /automount/radar/dwd/ry/2017/2017-08/2017-08-17/raa01-ry_10000-1708170940-dwd---bi*
# __________________________________________RY File Missing!
# 2017.08.17 -- 16:02:41
# 2017.08.17 -- 16:02:41
# /automount/radar/dwd/ry/2017/2017-08/2017-08-17/raa01-ry_10000-1708171600-dwd---bi*
# (659,)
# 2017.08.18 -- 08:45:17
# 2017.08.18 -- 08:45:17
# /automount/radar/dwd/ry/2017/2017-08/2017-08-18/raa01-ry_10000-1708180845-dwd---bi*
# not relevant polygon removed
# (579,)
# 2017.08.18 -- 15:09:41
# 2017.08.18 -- 15:09:41
# /automount/radar/dwd/ry/2017/2017-08/2017-08-18/raa01-ry_10000-1708181510-dwd---bi*
# not relevant polygon removed
# (453,)
# 2017.08.19 -- 07:52:19
# 2017.08.19 -- 07:52:19
# /automount/radar/dwd/ry/2017/2017-08/2017-08-19/raa01-ry_10000-1708190750-dwd---bi*
# not relevant polygon removed
# (563,)
# 2017.08.19 -- 14:16:59
# 2017.08.19 -- 14:16:59
# /automount/radar/dwd/ry/2017/2017-08/2017-08-19/raa01-ry_10000-1708191415-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.19 -- 15:52:33
# 2017.08.19 -- 15:52:33
# /automount/radar/dwd/ry/2017/2017-08/2017-08-19/raa01-ry_10000-1708191550-dwd---bi*
# not relevant polygon removed
# (433,)
# 2017.08.20 -- 06:59:24
# 2017.08.20 -- 06:59:24
# /automount/radar/dwd/ry/2017/2017-08/2017-08-20/raa01-ry_10000-170820755-dwd---bi*
# __________________________________________RY File Missing!
# 2017.08.20 -- 08:35:11
# 2017.08.20 -- 08:35:11
# /automount/radar/dwd/ry/2017/2017-08/2017-08-20/raa01-ry_10000-1708200835-dwd---bi*
# not relevant polygon removed
# (325,)
# 2017.08.20 -- 14:59:47
# 2017.08.20 -- 14:59:47
# /automount/radar/dwd/ry/2017/2017-08/2017-08-20/raa01-ry_10000-1708201555-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.08.21 -- 07:42:07
# 2017.08.21 -- 07:42:07
# /automount/radar/dwd/ry/2017/2017-08/2017-08-21/raa01-ry_10000-1708210740-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.08.21 -- 14:06:43
# 2017.08.21 -- 14:06:43
# /automount/radar/dwd/ry/2017/2017-08/2017-08-21/raa01-ry_10000-1708211405-dwd---bi*
# not relevant polygon removed
# (341,)
# 2017.08.21 -- 15:42:30
# 2017.08.21 -- 15:42:30
# /automount/radar/dwd/ry/2017/2017-08/2017-08-21/raa01-ry_10000-1708211540-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.22 -- 06:49:19
# 2017.08.22 -- 06:49:19
# /automount/radar/dwd/ry/2017/2017-08/2017-08-22/raa01-ry_10000-1708220650-dwd---bi*
# not relevant polygon removed
# (449,)
# 2017.08.22 -- 08:24:53
# 2017.08.22 -- 08:24:53
# /automount/radar/dwd/ry/2017/2017-08/2017-08-22/raa01-ry_10000-1708220825-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.22 -- 14:49:33
# 2017.08.22 -- 14:49:33
# /automount/radar/dwd/ry/2017/2017-08/2017-08-22/raa01-ry_10000-1708221450-dwd---bi*
# not relevant polygon removed
# (545,)
# 2017.08.23 -- 07:32:10
# 2017.08.23 -- 07:32:10
# /automount/radar/dwd/ry/2017/2017-08/2017-08-23/raa01-ry_10000-1708230730-dwd---bi*
# not relevant polygon removed
# (437,)
# 2017.08.23 -- 13:56:36
# 2017.08.23 -- 13:56:36
# /automount/radar/dwd/ry/2017/2017-08/2017-08-23/raa01-ry_10000-1708231355-dwd---bi*
# not relevant polygon removed
# (591,)
# 2017.08.24 -- 06:39:07
# 2017.08.24 -- 06:39:07
# /automount/radar/dwd/ry/2017/2017-08/2017-08-24/raa01-ry_10000-1708240640-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.08.24 -- 13:03:42
# 2017.08.24 -- 13:03:42
# /automount/radar/dwd/ry/2017/2017-08/2017-08-24/raa01-ry_10000-1708241305-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.24 -- 14:39:22
# 2017.08.24 -- 14:39:22
# /automount/radar/dwd/ry/2017/2017-08/2017-08-24/raa01-ry_10000-1708241440-dwd---bi*
# not relevant polygon removed
# (279,)
# 2017.08.25 -- 05:46:14
# 2017.08.25 -- 05:46:14
# /automount/radar/dwd/ry/2017/2017-08/2017-08-25/raa01-ry_10000-1708250545-dwd---bi*
# not relevant polygon removed
# (325,)
# 2017.08.25 -- 07:21:52
# 2017.08.25 -- 07:21:52
# /automount/radar/dwd/ry/2017/2017-08/2017-08-25/raa01-ry_10000-1708250720-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.25 -- 13:46:30
# 2017.08.25 -- 13:46:30
# /automount/radar/dwd/ry/2017/2017-08/2017-08-25/raa01-ry_10000-1708251345-dwd---bi*
# not relevant polygon removed
# (647,)
# 2017.08.26 -- 06:29:03
# 2017.08.26 -- 06:29:03
# /automount/radar/dwd/ry/2017/2017-08/2017-08-26/raa01-ry_10000-1708260630-dwd---bi*
# not relevant polygon removed
# (557,)
# 2017.08.26 -- 12:53:24
# 2017.08.26 -- 12:53:24
# /automount/radar/dwd/ry/2017/2017-08/2017-08-26/raa01-ry_10000-1708261255-dwd---bi*
# not relevant polygon removed
# (479,)
# 2017.08.27 -- 05:35:58
# 2017.08.27 -- 05:35:58
# /automount/radar/dwd/ry/2017/2017-08/2017-08-27/raa01-ry_10000-1708270535-dwd---bi*
# not relevant polygon removed
# (585,)
# 2017.08.27 -- 12:00:37
# 2017.08.27 -- 12:00:37
# /automount/radar/dwd/ry/2017/2017-08/2017-08-27/raa01-ry_10000-1708271200-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.27 -- 13:36:11
# 2017.08.27 -- 13:36:11
# /automount/radar/dwd/ry/2017/2017-08/2017-08-27/raa01-ry_10000-1708271335-dwd---bi*
# not relevant polygon removed
# (407,)
# 2017.08.28 -- 04:43:01
# 2017.08.28 -- 04:43:01
# /automount/radar/dwd/ry/2017/2017-08/2017-08-28/raa01-ry_10000-1708280445-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.28 -- 06:18:46
# 2017.08.28 -- 06:18:46
# /automount/radar/dwd/ry/2017/2017-08/2017-08-28/raa01-ry_10000-1708280620-dwd---bi*
# not relevant polygon removed
# (303,)
# 2017.08.28 -- 12:43:21
# 2017.08.28 -- 12:43:21
# /automount/radar/dwd/ry/2017/2017-08/2017-08-28/raa01-ry_10000-1708281245-dwd---bi*
# not relevant polygon removed
# not relevant polygon removed
# (661,)
# 2017.08.29 -- 05:25:40
# 2017.08.29 -- 05:25:40
# /automount/radar/dwd/ry/2017/2017-08/2017-08-29/raa01-ry_10000-1708290525-dwd---bi*
# not relevant polygon removed
# (645,)
# 2017.08.29 -- 11:50:13
# 2017.08.29 -- 11:50:13
# /automount/radar/dwd/ry/2017/2017-08/2017-08-29/raa01-ry_10000-1708291150-dwd---bi*
# not relevant polygon removed
# (365,)
# 2017.08.29 -- 13:26:01
# 2017.08.29 -- 13:26:01
# /automount/radar/dwd/ry/2017/2017-08/2017-08-29/raa01-ry_10000-1708291325-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.08.30 -- 04:32:47
# 2017.08.30 -- 04:32:47
# /automount/radar/dwd/ry/2017/2017-08/2017-08-30/raa01-ry_10000-1708300430-dwd---bi*
# not relevant polygon removed
# not relevant polygon removed
# (473,)
# 2017.08.30 -- 12:32:59
# 2017.08.30 -- 12:32:59
# /automount/radar/dwd/ry/2017/2017-08/2017-08-30/raa01-ry_10000-1708301230-dwd---bi*
# not relevant polygon removed
# (525,)
# 2017.08.31 -- 05:16:03
# 2017.08.31 -- 05:16:03
# /automount/radar/dwd/ry/2017/2017-08/2017-08-31/raa01-ry_10000-1708310515-dwd---bi*
# not relevant polygon removed
# (409,)
# 2017.08.31 -- 11:40:42
# 2017.08.31 -- 11:40:42
# /automount/radar/dwd/ry/2017/2017-08/2017-08-31/raa01-ry_10000-1708311140-dwd---bi*
# not relevant polygon removed
# (613,)
# 2017.09.01 -- 04:23:39
# 2017.09.01 -- 04:23:39
# /automount/radar/dwd/ry/2017/2017-09/2017-09-01/raa01-ry_10000-1709010425-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.09.01 -- 10:48:25
# 2017.09.01 -- 10:48:25
# /automount/radar/dwd/ry/2017/2017-09/2017-09-01/raa01-ry_10000-1709011050-dwd---bi*
# not relevant polygon removed
# (269,)
# 2017.09.01 -- 12:24:10
# 2017.09.01 -- 12:24:10
# /automount/radar/dwd/ry/2017/2017-09/2017-09-01/raa01-ry_10000-1709011225-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.02 -- 03:31:29
# 2017.09.02 -- 03:31:29
# /automount/radar/dwd/ry/2017/2017-09/2017-09-02/raa01-ry_10000-1709020330-dwd---bi*
# not relevant polygon removed
# (371,)
# 2017.09.02 -- 05:07:08
# 2017.09.02 -- 05:07:08
# /automount/radar/dwd/ry/2017/2017-09/2017-09-02/raa01-ry_10000-1709020505-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.02 -- 11:31:57
# 2017.09.02 -- 11:31:57
# /automount/radar/dwd/ry/2017/2017-09/2017-09-02/raa01-ry_10000-1709021130-dwd---bi*
# not relevant polygon removed
# (613,)
# 2017.09.03 -- 04:15:01
# 2017.09.03 -- 04:15:01
# /automount/radar/dwd/ry/2017/2017-09/2017-09-03/raa01-ry_10000-1709030415-dwd---bi*
# not relevant polygon removed
# (509,)
# 2017.09.03 -- 10:39:33
# 2017.09.03 -- 10:39:33
# /automount/radar/dwd/ry/2017/2017-09/2017-09-03/raa01-ry_10000-1709031040-dwd---bi*
# not relevant polygon removed
# (533,)
# 2017.09.04 -- 03:22:34
# 2017.09.04 -- 03:22:34
# /automount/radar/dwd/ry/2017/2017-09/2017-09-04/raa01-ry_10000-1709040320-dwd---bi*
# not relevant polygon removed
# (635,)
# 2017.09.04 -- 09:47:23
# 2017.09.04 -- 09:47:23
# /automount/radar/dwd/ry/2017/2017-09/2017-09-04/raa01-ry_10000-1709040945-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.04 -- 11:23:03
# 2017.09.04 -- 11:23:03
# /automount/radar/dwd/ry/2017/2017-09/2017-09-04/raa01-ry_10000-1709041125-dwd---bi*
# not relevant polygon removed
# (345,)
# 2017.09.05 -- 02:30:20
# 2017.09.05 -- 02:30:20
# /automount/radar/dwd/ry/2017/2017-09/2017-09-05/raa01-ry_10000-1709050230-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.05 -- 04:06:04
# 2017.09.05 -- 04:06:04
# /automount/radar/dwd/ry/2017/2017-09/2017-09-05/raa01-ry_10000-1709050405-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.05 -- 10:30:49
# 2017.09.05 -- 10:30:49
# /automount/radar/dwd/ry/2017/2017-09/2017-09-05/raa01-ry_10000-1709051030-dwd---bi*
# not relevant polygon removed
# (661,)
# 2017.09.06 -- 03:13:47
# 2017.09.06 -- 03:13:47
# /automount/radar/dwd/ry/2017/2017-09/2017-09-06/raa01-ry_10000-1709060315-dwd---bi*
# not relevant polygon removed
# (595,)
# 2017.09.06 -- 09:38:23
# 2017.09.06 -- 09:38:23
# /automount/radar/dwd/ry/2017/2017-09/2017-09-06/raa01-ry_10000-1709060940-dwd---bi*
# not relevant polygon removed
# (435,)
# 2017.09.07 -- 02:21:24
# 2017.09.07 -- 02:21:24
# /automount/radar/dwd/ry/2017/2017-09/2017-09-07/raa01-ry_10000-1709070220-dwd---bi*
# not relevant polygon removed
# (547,)
# 2017.09.07 -- 08:46:15
# 2017.09.07 -- 08:46:15
# /automount/radar/dwd/ry/2017/2017-09/2017-09-07/raa01-ry_10000-1709070845-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.07 -- 10:21:50
# 2017.09.07 -- 10:21:50
# /automount/radar/dwd/ry/2017/2017-09/2017-09-07/raa01-ry_10000-1709071020-dwd---bi*
# not relevant polygon removed
# (447,)
# 2017.09.08 -- 01:29:02
# 2017.09.08 -- 01:29:02
# /automount/radar/dwd/ry/2017/2017-09/2017-09-08/raa01-ry_10000-1709080130-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.08 -- 03:04:52
# 2017.09.08 -- 03:04:52
# /automount/radar/dwd/ry/2017/2017-09/2017-09-08/raa01-ry_10000-1709080305-dwd---bi*
# not relevant polygon removed
# (335,)
# 2017.09.08 -- 09:29:37
# 2017.09.08 -- 09:29:37
# /automount/radar/dwd/ry/2017/2017-09/2017-09-08/raa01-ry_10000-1709080930-dwd---bi*
# (659,)
# 2017.09.09 -- 02:12:19
# 2017.09.09 -- 02:12:19
# /automount/radar/dwd/ry/2017/2017-09/2017-09-09/raa01-ry_10000-1709090210-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.09.09 -- 08:37:04
# 2017.09.09 -- 08:37:04
# /automount/radar/dwd/ry/2017/2017-09/2017-09-09/raa01-ry_10000-1709090835-dwd---bi*
# (339,)
# 2017.09.09 -- 10:12:52
# 2017.09.09 -- 10:12:52
# /automount/radar/dwd/ry/2017/2017-09/2017-09-09/raa01-ry_10000-1709091010-dwd---bi*
# __________________________________________RY File Missing!
# 2017.09.10 -- 01:20:04
# 2017.09.10 -- 01:20:04
# /automount/radar/dwd/ry/2017/2017-09/2017-09-10/raa01-ry_10000-1709100120-dwd---bi*
# (451,)
# 2017.09.10 -- 02:55:38
# 2017.09.10 -- 02:55:38
# /automount/radar/dwd/ry/2017/2017-09/2017-09-10/raa01-ry_10000-1709100255-dwd---bi*
# __________________________________________RY File Missing!
# 2017.09.10 -- 09:20:28
# 2017.09.10 -- 09:20:28
# /automount/radar/dwd/ry/2017/2017-09/2017-09-10/raa01-ry_10000-1709100920-dwd---bi*
# (545,)
# 2017.09.11 -- 02:03:26
# 2017.09.11 -- 02:03:26
# /automount/radar/dwd/ry/2017/2017-09/2017-09-11/raa01-ry_10000-1709110205-dwd---bi*
# (429,)
# 2017.09.11 -- 08:28:00
# 2017.09.11 -- 08:28:00
# /automount/radar/dwd/ry/2017/2017-09/2017-09-11/raa01-ry_10000-1709110830-dwd---bi*
# not relevant polygon removed
# (597,)
# 2017.09.12 -- 01:10:52
# 2017.09.12 -- 01:10:52
# /automount/radar/dwd/ry/2017/2017-09/2017-09-12/raa01-ry_10000-1709120110-dwd---bi*
# not relevant polygon removed
# (661,)
# 2017.09.12 -- 07:35:36
# 2017.09.12 -- 07:35:36
# /automount/radar/dwd/ry/2017/2017-09/2017-09-12/raa01-ry_10000-1709120735-dwd---bi*
# not relevant polygon removed
# (249,)
# 2017.09.12 -- 09:11:20
# 2017.09.12 -- 09:11:20
# /automount/radar/dwd/ry/2017/2017-09/2017-09-12/raa01-ry_10000-1709120910-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.13 -- 00:18:32
# 2017.09.13 -- 00:18:32
# /automount/radar/dwd/ry/2017/2017-09/2017-09-13/raa01-ry_10000-1709130020-dwd---bi*
# not relevant polygon removed
# (345,)
# 2017.09.13 -- 01:54:10
# 2017.09.13 -- 01:54:10
# /automount/radar/dwd/ry/2017/2017-09/2017-09-13/raa01-ry_10000-1709130155-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.13 -- 08:18:58
# 2017.09.13 -- 08:18:58
# /automount/radar/dwd/ry/2017/2017-09/2017-09-13/raa01-ry_10000-1709130820-dwd---bi*
# not relevant polygon removed
# (635,)
# 2017.09.14 -- 01:01:52
# 2017.09.14 -- 01:01:52
# /automount/radar/dwd/ry/2017/2017-09/2017-09-14/raa01-ry_10000-1709140100-dwd---bi*
# not relevant polygon removed
# (533,)
# 2017.09.14 -- 07:26:21
# 2017.09.14 -- 07:26:21
# /automount/radar/dwd/ry/2017/2017-09/2017-09-14/raa01-ry_10000-1709140725-dwd---bi*
# not relevant polygon removed
# (505,)
# 2017.09.15 -- 00:09:17
# 2017.09.15 -- 00:09:17
# /automount/radar/dwd/ry/2017/2017-09/2017-09-15/raa01-ry_10000-1709150010-dwd---bi*
# not relevant polygon removed
# (609,)
# 2017.09.15 -- 06:34:03
# 2017.09.15 -- 06:34:03
# /automount/radar/dwd/ry/2017/2017-09/2017-09-15/raa01-ry_10000-1709150635-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.15 -- 08:09:41
# 2017.09.15 -- 08:09:41
# /automount/radar/dwd/ry/2017/2017-09/2017-09-15/raa01-ry_10000-1709150810-dwd---bi*
# not relevant polygon removed
# (375,)
# 2017.09.15 -- 23:16:58
# 2017.09.15 -- 23:16:58
# /automount/radar/dwd/ry/2017/2017-09/2017-09-15/raa01-ry_10000-1709152315-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.16 -- 00:52:43
# 2017.09.16 -- 00:52:43
# /automount/radar/dwd/ry/2017/2017-09/2017-09-16/raa01-ry_10000-1709160050-dwd---bi*
# not relevant polygon removed
# (271,)
# 2017.09.16 -- 07:17:30
# 2017.09.16 -- 07:17:30
# /automount/radar/dwd/ry/2017/2017-09/2017-09-16/raa01-ry_10000-1709160715-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.09.17 -- 00:00:27
# 2017.09.17 -- 00:00:27
# /automount/radar/dwd/ry/2017/2017-09/2017-09-17/raa01-ry_10000-1709170000-dwd---bi*
# not relevant polygon removed
# (613,)
# 2017.09.17 -- 06:25:07
# 2017.09.17 -- 06:25:07
# /automount/radar/dwd/ry/2017/2017-09/2017-09-17/raa01-ry_10000-1709170625-dwd---bi*
# not relevant polygon removed
# (407,)
# 2017.09.17 -- 23:08:15
# 2017.09.17 -- 23:08:15
# /automount/radar/dwd/ry/2017/2017-09/2017-09-17/raa01-ry_10000-1709172310-dwd---bi*
# not relevant polygon removed
# (521,)
# 2017.09.18 -- 07:08:42
# 2017.09.18 -- 07:08:42
# /automount/radar/dwd/ry/2017/2017-09/2017-09-18/raa01-ry_10000-1709180710-dwd---bi*
# not relevant polygon removed
# (475,)
# 2017.09.18 -- 22:15:58
# 2017.09.18 -- 22:15:58
# /automount/radar/dwd/ry/2017/2017-09/2017-09-18/raa01-ry_10000-1709182215-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.18 -- 23:51:48
# 2017.09.18 -- 23:51:48
# /automount/radar/dwd/ry/2017/2017-09/2017-09-18/raa01-ry_10000-1709182350-dwd---bi*
# not relevant polygon removed
# (359,)
# 2017.09.19 -- 06:16:33
# 2017.09.19 -- 06:16:33
# /automount/radar/dwd/ry/2017/2017-09/2017-09-19/raa01-ry_10000-1709190615-dwd---bi*
# not relevant polygon removed
# (649,)
# 2017.09.19 -- 22:59:24
# 2017.09.19 -- 22:59:24
# /automount/radar/dwd/ry/2017/2017-09/2017-09-19/raa01-ry_10000-1709192355-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.09.20 -- 05:24:10
# 2017.09.20 -- 05:24:10
# /automount/radar/dwd/ry/2017/2017-09/2017-09-20/raa01-ry_10000-1709200525-dwd---bi*
# not relevant polygon removed
# (317,)
# 2017.09.20 -- 06:59:59
# 2017.09.20 -- 06:59:59
# /automount/radar/dwd/ry/2017/2017-09/2017-09-20/raa01-ry_10000-170920755-dwd---bi*
# __________________________________________RY File Missing!
# 2017.09.20 -- 22:07:16
# 2017.09.20 -- 22:07:16
# /automount/radar/dwd/ry/2017/2017-09/2017-09-20/raa01-ry_10000-1709202205-dwd---bi*
# not relevant polygon removed
# (429,)
# 2017.09.20 -- 23:42:53
# 2017.09.20 -- 23:42:53
# /automount/radar/dwd/ry/2017/2017-09/2017-09-20/raa01-ry_10000-1709202340-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.21 -- 06:07:44
# 2017.09.21 -- 06:07:44
# /automount/radar/dwd/ry/2017/2017-09/2017-09-21/raa01-ry_10000-1709210605-dwd---bi*
# not relevant polygon removed
# (565,)
# 2017.09.21 -- 22:50:48
# 2017.09.21 -- 22:50:48
# /automount/radar/dwd/ry/2017/2017-09/2017-09-21/raa01-ry_10000-1709212250-dwd---bi*
# not relevant polygon removed
# (451,)
# 2017.09.22 -- 05:15:23
# 2017.09.22 -- 05:15:23
# /automount/radar/dwd/ry/2017/2017-09/2017-09-22/raa01-ry_10000-1709220515-dwd---bi*
# not relevant polygon removed
# (583,)
# 2017.09.22 -- 21:58:25
# 2017.09.22 -- 21:58:25
# /automount/radar/dwd/ry/2017/2017-09/2017-09-22/raa01-ry_10000-1709222255-dwd---bi*
# not relevant polygon removed
# (661,)
# 2017.09.23 -- 04:23:11
# 2017.09.23 -- 04:23:11
# /automount/radar/dwd/ry/2017/2017-09/2017-09-23/raa01-ry_10000-1709230425-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.23 -- 05:58:53
# 2017.09.23 -- 05:58:53
# /automount/radar/dwd/ry/2017/2017-09/2017-09-23/raa01-ry_10000-170923655-dwd---bi*
# __________________________________________RY File Missing!
# 2017.09.23 -- 21:06:12
# 2017.09.23 -- 21:06:12
# /automount/radar/dwd/ry/2017/2017-09/2017-09-23/raa01-ry_10000-1709232105-dwd---bi*
# not relevant polygon removed
# (325,)
# 2017.09.23 -- 22:41:52
# 2017.09.23 -- 22:41:52
# /automount/radar/dwd/ry/2017/2017-09/2017-09-23/raa01-ry_10000-1709232240-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.24 -- 05:06:42
# 2017.09.24 -- 05:06:42
# /automount/radar/dwd/ry/2017/2017-09/2017-09-24/raa01-ry_10000-1709240505-dwd---bi*
# not relevant polygon removed
# (647,)
# 2017.09.24 -- 21:49:43
# 2017.09.24 -- 21:49:43
# /automount/radar/dwd/ry/2017/2017-09/2017-09-24/raa01-ry_10000-1709242150-dwd---bi*
# not relevant polygon removed
# (553,)
# 2017.09.25 -- 04:14:15
# 2017.09.25 -- 04:14:15
# /automount/radar/dwd/ry/2017/2017-09/2017-09-25/raa01-ry_10000-1709250415-dwd---bi*
# not relevant polygon removed
# (489,)
# 2017.09.25 -- 20:57:19
# 2017.09.25 -- 20:57:19
# /automount/radar/dwd/ry/2017/2017-09/2017-09-25/raa01-ry_10000-1709252055-dwd---bi*
# not relevant polygon removed
# (597,)
# 2017.09.26 -- 03:22:07
# 2017.09.26 -- 03:22:07
# /automount/radar/dwd/ry/2017/2017-09/2017-09-26/raa01-ry_10000-1709260320-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.09.26 -- 04:57:47
# 2017.09.26 -- 04:57:47
# /automount/radar/dwd/ry/2017/2017-09/2017-09-26/raa01-ry_10000-1709260455-dwd---bi*
# not relevant polygon removed
# (391,)
# 2017.09.29 -- 20:39:37
# 2017.09.29 -- 20:39:37
# /automount/radar/dwd/ry/2017/2017-09/2017-09-29/raa01-ry_10000-1709292040-dwd---bi*
# not relevant polygon removed
# (375,)
# 2017.09.30 -- 03:04:19
# 2017.09.30 -- 03:04:19
# /automount/radar/dwd/ry/2017/2017-09/2017-09-30/raa01-ry_10000-1709300305-dwd---bi*
# not relevant polygon removed
# (637,)
# 2017.09.30 -- 19:47:08
# 2017.09.30 -- 19:47:08
# /automount/radar/dwd/ry/2017/2017-09/2017-09-30/raa01-ry_10000-1709301945-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.10.01 -- 02:11:52
# 2017.10.01 -- 02:11:52
# /automount/radar/dwd/ry/2017/2017-10/2017-10-01/raa01-ry_10000-1710010210-dwd---bi*
# not relevant polygon removed
# (301,)
# 2017.10.01 -- 03:47:40
# 2017.10.01 -- 03:47:40
# /automount/radar/dwd/ry/2017/2017-10/2017-10-01/raa01-ry_10000-1710010345-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.01 -- 18:54:53
# 2017.10.01 -- 18:54:53
# /automount/radar/dwd/ry/2017/2017-10/2017-10-01/raa01-ry_10000-1710011855-dwd---bi*
# not relevant polygon removed
# (409,)
# 2017.10.01 -- 20:30:30
# 2017.10.01 -- 20:30:30
# /automount/radar/dwd/ry/2017/2017-10/2017-10-01/raa01-ry_10000-1710012030-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.02 -- 02:55:19
# 2017.10.02 -- 02:55:19
# /automount/radar/dwd/ry/2017/2017-10/2017-10-02/raa01-ry_10000-1710020255-dwd---bi*
# not relevant polygon removed
# (583,)
# 2017.10.02 -- 19:38:19
# 2017.10.02 -- 19:38:19
# /automount/radar/dwd/ry/2017/2017-10/2017-10-02/raa01-ry_10000-1710021940-dwd---bi*
# not relevant polygon removed
# (471,)
# 2017.10.03 -- 02:02:50
# 2017.10.03 -- 02:02:50
# /automount/radar/dwd/ry/2017/2017-10/2017-10-03/raa01-ry_10000-1710030200-dwd---bi*
# not relevant polygon removed
# (569,)
# 2017.10.03 -- 18:45:50
# 2017.10.03 -- 18:45:50
# /automount/radar/dwd/ry/2017/2017-10/2017-10-03/raa01-ry_10000-1710031845-dwd---bi*
# not relevant polygon removed
# (655,)
# 2017.10.04 -- 01:10:34
# 2017.10.04 -- 01:10:34
# /automount/radar/dwd/ry/2017/2017-10/2017-10-04/raa01-ry_10000-1710040110-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.04 -- 02:46:16
# 2017.10.04 -- 02:46:16
# /automount/radar/dwd/ry/2017/2017-10/2017-10-04/raa01-ry_10000-1710040245-dwd---bi*
# not relevant polygon removed
# (309,)
# 2017.10.04 -- 17:53:31
# 2017.10.04 -- 17:53:31
# /automount/radar/dwd/ry/2017/2017-10/2017-10-04/raa01-ry_10000-1710041755-dwd---bi*
# not relevant polygon removed
# (301,)
# 2017.10.04 -- 19:29:12
# 2017.10.04 -- 19:29:12
# /automount/radar/dwd/ry/2017/2017-10/2017-10-04/raa01-ry_10000-1710041930-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.05 -- 01:53:57
# 2017.10.05 -- 01:53:57
# /automount/radar/dwd/ry/2017/2017-10/2017-10-05/raa01-ry_10000-1710050155-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.10.05 -- 18:36:54
# 2017.10.05 -- 18:36:54
# /automount/radar/dwd/ry/2017/2017-10/2017-10-05/raa01-ry_10000-1710051835-dwd---bi*
# not relevant polygon removed
# (573,)
# 2017.10.06 -- 01:01:26
# 2017.10.06 -- 01:01:26
# /automount/radar/dwd/ry/2017/2017-10/2017-10-06/raa01-ry_10000-1710060100-dwd---bi*
# not relevant polygon removed
# (465,)
# 2017.10.06 -- 17:44:26
# 2017.10.06 -- 17:44:26
# /automount/radar/dwd/ry/2017/2017-10/2017-10-06/raa01-ry_10000-1710061745-dwd---bi*
# not relevant polygon removed
# (575,)
# 2017.10.07 -- 00:09:13
# 2017.10.07 -- 00:09:13
# /automount/radar/dwd/ry/2017/2017-10/2017-10-07/raa01-ry_10000-1710070010-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.07 -- 01:44:50
# 2017.10.07 -- 01:44:50
# /automount/radar/dwd/ry/2017/2017-10/2017-10-07/raa01-ry_10000-1710070145-dwd---bi*
# not relevant polygon removed
# (417,)
# 2017.10.07 -- 16:52:02
# 2017.10.07 -- 16:52:02
# /automount/radar/dwd/ry/2017/2017-10/2017-10-07/raa01-ry_10000-1710071650-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.07 -- 18:27:47
# 2017.10.07 -- 18:27:47
# /automount/radar/dwd/ry/2017/2017-10/2017-10-07/raa01-ry_10000-1710071825-dwd---bi*
# not relevant polygon removed
# (305,)
# 2017.10.08 -- 00:52:32
# 2017.10.08 -- 00:52:32
# /automount/radar/dwd/ry/2017/2017-10/2017-10-08/raa01-ry_10000-1710080050-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.10.08 -- 17:35:15
# 2017.10.08 -- 17:35:15
# /automount/radar/dwd/ry/2017/2017-10/2017-10-08/raa01-ry_10000-1710081735-dwd---bi*
# not relevant polygon removed
# (645,)
# 2017.10.08 -- 23:59:57
# 2017.10.08 -- 23:59:57
# /automount/radar/dwd/ry/2017/2017-10/2017-10-9/raa01-ry_10000-171092455-dwd---bi*
# __________________________________________RY File Missing!
# 2017.10.09 -- 01:35:48
# 2017.10.09 -- 01:35:48
# /automount/radar/dwd/ry/2017/2017-10/2017-10-09/raa01-ry_10000-1710090135-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.09 -- 16:42:56
# 2017.10.09 -- 16:42:56
# /automount/radar/dwd/ry/2017/2017-10/2017-10-09/raa01-ry_10000-1710091640-dwd---bi*
# not relevant polygon removed
# (479,)
# 2017.10.10 -- 00:43:19
# 2017.10.10 -- 00:43:19
# /automount/radar/dwd/ry/2017/2017-10/2017-10-10/raa01-ry_10000-1710100045-dwd---bi*
# not relevant polygon removed
# (517,)
# 2017.10.10 -- 17:26:16
# 2017.10.10 -- 17:26:16
# /automount/radar/dwd/ry/2017/2017-10/2017-10-10/raa01-ry_10000-1710101725-dwd---bi*
# not relevant polygon removed
# (401,)
# 2017.10.10 -- 23:50:53
# 2017.10.10 -- 23:50:53
# /automount/radar/dwd/ry/2017/2017-10/2017-10-10/raa01-ry_10000-1710102350-dwd---bi*
# not relevant polygon removed
# (617,)
# 2017.10.11 -- 16:33:42
# 2017.10.11 -- 16:33:42
# /automount/radar/dwd/ry/2017/2017-10/2017-10-11/raa01-ry_10000-1710111635-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.10.11 -- 22:58:24
# 2017.10.11 -- 22:58:24
# /automount/radar/dwd/ry/2017/2017-10/2017-10-11/raa01-ry_10000-1710112355-dwd---bi*
# not relevant polygon removed
# (273,)
# 2017.10.12 -- 00:34:10
# 2017.10.12 -- 00:34:10
# /automount/radar/dwd/ry/2017/2017-10/2017-10-12/raa01-ry_10000-1710120035-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.12 -- 15:41:20
# 2017.10.12 -- 15:41:20
# /automount/radar/dwd/ry/2017/2017-10/2017-10-12/raa01-ry_10000-1710121540-dwd---bi*
# not relevant polygon removed
# (377,)
# 2017.10.12 -- 17:16:58
# 2017.10.12 -- 17:16:58
# /automount/radar/dwd/ry/2017/2017-10/2017-10-12/raa01-ry_10000-1710121715-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.12 -- 23:41:45
# 2017.10.12 -- 23:41:45
# /automount/radar/dwd/ry/2017/2017-10/2017-10-12/raa01-ry_10000-1710122340-dwd---bi*
# not relevant polygon removed
# (611,)
# 2017.10.13 -- 16:24:39
# 2017.10.13 -- 16:24:39
# /automount/radar/dwd/ry/2017/2017-10/2017-10-13/raa01-ry_10000-1710131625-dwd---bi*
# not relevant polygon removed
# (503,)
# 2017.10.13 -- 22:49:08
# 2017.10.13 -- 22:49:08
# /automount/radar/dwd/ry/2017/2017-10/2017-10-13/raa01-ry_10000-1710132250-dwd---bi*
# not relevant polygon removed
# (537,)
# 2017.10.14 -- 15:32:02
# 2017.10.14 -- 15:32:02
# /automount/radar/dwd/ry/2017/2017-10/2017-10-14/raa01-ry_10000-1710141530-dwd---bi*
# not relevant polygon removed
# (633,)
# 2017.10.14 -- 21:56:47
# 2017.10.14 -- 21:56:47
# /automount/radar/dwd/ry/2017/2017-10/2017-10-14/raa01-ry_10000-1710142155-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.14 -- 23:32:26
# 2017.10.14 -- 23:32:26
# /automount/radar/dwd/ry/2017/2017-10/2017-10-14/raa01-ry_10000-1710142330-dwd---bi*
# not relevant polygon removed
# (345,)
# 2017.10.15 -- 14:39:36
# 2017.10.15 -- 14:39:36
# /automount/radar/dwd/ry/2017/2017-10/2017-10-15/raa01-ry_10000-1710151440-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.15 -- 16:15:18
# 2017.10.15 -- 16:15:18
# /automount/radar/dwd/ry/2017/2017-10/2017-10-15/raa01-ry_10000-1710151615-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.15 -- 22:40:01
# 2017.10.15 -- 22:40:01
# /automount/radar/dwd/ry/2017/2017-10/2017-10-15/raa01-ry_10000-1710152240-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.10.16 -- 15:22:49
# 2017.10.16 -- 15:22:49
# /automount/radar/dwd/ry/2017/2017-10/2017-10-16/raa01-ry_10000-1710161520-dwd---bi*
# not relevant polygon removed
# (597,)
# 2017.10.16 -- 21:47:22
# 2017.10.16 -- 21:47:22
# /automount/radar/dwd/ry/2017/2017-10/2017-10-16/raa01-ry_10000-1710162145-dwd---bi*
# not relevant polygon removed
# (429,)
# 2017.10.17 -- 14:30:17
# 2017.10.17 -- 14:30:17
# /automount/radar/dwd/ry/2017/2017-10/2017-10-17/raa01-ry_10000-1710171430-dwd---bi*
# not relevant polygon removed
# (541,)
# 2017.10.17 -- 20:55:04
# 2017.10.17 -- 20:55:04
# /automount/radar/dwd/ry/2017/2017-10/2017-10-17/raa01-ry_10000-1710172055-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.17 -- 22:30:39
# 2017.10.17 -- 22:30:39
# /automount/radar/dwd/ry/2017/2017-10/2017-10-17/raa01-ry_10000-1710172230-dwd---bi*
# not relevant polygon removed
# (455,)
# 2017.10.18 -- 13:37:44
# 2017.10.18 -- 13:37:44
# /automount/radar/dwd/ry/2017/2017-10/2017-10-18/raa01-ry_10000-1710181335-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.10.18 -- 15:13:32
# 2017.10.18 -- 15:13:32
# /automount/radar/dwd/ry/2017/2017-10/2017-10-18/raa01-ry_10000-1710181515-dwd---bi*
# not relevant polygon removed
# (343,)
# 2017.10.18 -- 21:38:14
# 2017.10.18 -- 21:38:14
# /automount/radar/dwd/ry/2017/2017-10/2017-10-18/raa01-ry_10000-1710182140-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.10.19 -- 14:20:50
# 2017.10.19 -- 14:20:50
# /automount/radar/dwd/ry/2017/2017-10/2017-10-19/raa01-ry_10000-1710191420-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.10.19 -- 20:45:32
# 2017.10.19 -- 20:45:32
# /automount/radar/dwd/ry/2017/2017-10/2017-10-19/raa01-ry_10000-1710192045-dwd---bi*
# not relevant polygon removed
# (329,)
# 2017.10.19 -- 22:21:20
# 2017.10.19 -- 22:21:20
# ...
# __________________________________________RY File Missing!
# 2017.12.03 -- 02:04:37
# 2017.12.03 -- 02:04:37
# /automount/radar/dwd/ry/2017/2017-12/2017-12-03/raa01-ry_10000-1712030205-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.03 -- 08:29:19
# 2017.12.03 -- 08:29:19
# /automount/radar/dwd/ry/2017/2017-12/2017-12-03/raa01-ry_10000-1712030830-dwd---bi*
# not relevant polygon removed
# (661,)
# 2017.12.04 -- 01:12:05
# 2017.12.04 -- 01:12:05
# /automount/radar/dwd/ry/2017/2017-12/2017-12-04/raa01-ry_10000-1712040110-dwd---bi*
# not relevant polygon removed
# (607,)
# 2017.12.04 -- 07:36:39
# 2017.12.04 -- 07:36:39
# /automount/radar/dwd/ry/2017/2017-12/2017-12-04/raa01-ry_10000-1712040735-dwd---bi*
# not relevant polygon removed
# (415,)
# 2017.12.05 -- 00:19:34
# 2017.12.05 -- 00:19:34
# /automount/radar/dwd/ry/2017/2017-12/2017-12-05/raa01-ry_10000-1712050020-dwd---bi*
# not relevant polygon removed
# (527,)
# 2017.12.05 -- 08:19:54
# 2017.12.05 -- 08:19:54
# /automount/radar/dwd/ry/2017/2017-12/2017-12-05/raa01-ry_10000-1712050820-dwd---bi*
# not relevant polygon removed
# (469,)
# 2017.12.05 -- 23:26:59
# 2017.12.05 -- 23:26:59
# /automount/radar/dwd/ry/2017/2017-12/2017-12-05/raa01-ry_10000-1712052325-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.06 -- 01:02:47
# 2017.12.06 -- 01:02:47
# /automount/radar/dwd/ry/2017/2017-12/2017-12-06/raa01-ry_10000-1712060100-dwd---bi*
# not relevant polygon removed
# (357,)
# 2017.12.06 -- 07:27:28
# 2017.12.06 -- 07:27:28
# /automount/radar/dwd/ry/2017/2017-12/2017-12-06/raa01-ry_10000-1712060725-dwd---bi*
# not relevant polygon removed
# (653,)
# 2017.12.07 -- 00:10:05
# 2017.12.07 -- 00:10:05
# /automount/radar/dwd/ry/2017/2017-12/2017-12-07/raa01-ry_10000-1712070010-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.12.07 -- 06:34:46
# 2017.12.07 -- 06:34:46
# /automount/radar/dwd/ry/2017/2017-12/2017-12-07/raa01-ry_10000-1712070635-dwd---bi*
# not relevant polygon removed
# (315,)
# 2017.12.07 -- 08:10:33
# 2017.12.07 -- 08:10:33
# /automount/radar/dwd/ry/2017/2017-12/2017-12-07/raa01-ry_10000-1712070810-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.07 -- 23:17:33
# 2017.12.07 -- 23:17:33
# /automount/radar/dwd/ry/2017/2017-12/2017-12-07/raa01-ry_10000-1712072315-dwd---bi*
# not relevant polygon removed
# (423,)
# 2017.12.08 -- 00:53:07
# 2017.12.08 -- 00:53:07
# /automount/radar/dwd/ry/2017/2017-12/2017-12-08/raa01-ry_10000-1712080055-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.08 -- 07:17:48
# 2017.12.08 -- 07:17:48
# /automount/radar/dwd/ry/2017/2017-12/2017-12-08/raa01-ry_10000-1712080715-dwd---bi*
# not relevant polygon removed
# (571,)
# 2017.12.09 -- 00:00:27
# 2017.12.09 -- 00:00:27
# /automount/radar/dwd/ry/2017/2017-12/2017-12-09/raa01-ry_10000-1712090000-dwd---bi*
# not relevant polygon removed
# (463,)
# 2017.12.09 -- 06:24:50
# 2017.12.09 -- 06:24:50
# /automount/radar/dwd/ry/2017/2017-12/2017-12-09/raa01-ry_10000-1712090625-dwd---bi*
# not relevant polygon removed
# (573,)
# 2017.12.09 -- 23:07:27
# 2017.12.09 -- 23:07:27
# /automount/radar/dwd/ry/2017/2017-12/2017-12-09/raa01-ry_10000-1712092305-dwd---bi*
# not relevant polygon removed
# (653,)
# 2017.12.10 -- 05:32:04
# 2017.12.10 -- 05:32:04
# /automount/radar/dwd/ry/2017/2017-12/2017-12-10/raa01-ry_10000-1712100530-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.10 -- 07:07:44
# 2017.12.10 -- 07:07:44
# /automount/radar/dwd/ry/2017/2017-12/2017-12-10/raa01-ry_10000-1712100705-dwd---bi*
# not relevant polygon removed
# (307,)
# 2017.12.10 -- 22:14:39
# 2017.12.10 -- 22:14:39
# /automount/radar/dwd/ry/2017/2017-12/2017-12-10/raa01-ry_10000-1712102215-dwd---bi*
# not relevant polygon removed
# (299,)
# 2017.12.10 -- 23:50:18
# 2017.12.10 -- 23:50:18
# /automount/radar/dwd/ry/2017/2017-12/2017-12-10/raa01-ry_10000-1712102350-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.11 -- 06:14:54
# 2017.12.11 -- 06:14:54
# /automount/radar/dwd/ry/2017/2017-12/2017-12-11/raa01-ry_10000-1712110615-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.12.11 -- 22:57:30
# 2017.12.11 -- 22:57:30
# /automount/radar/dwd/ry/2017/2017-12/2017-12-11/raa01-ry_10000-1712112255-dwd---bi*
# not relevant polygon removed
# (577,)
# 2017.12.12 -- 05:21:54
# 2017.12.12 -- 05:21:54
# /automount/radar/dwd/ry/2017/2017-12/2017-12-12/raa01-ry_10000-1712120520-dwd---bi*
# not relevant polygon removed
# (455,)
# 2017.12.12 -- 22:04:33
# 2017.12.12 -- 22:04:33
# /automount/radar/dwd/ry/2017/2017-12/2017-12-12/raa01-ry_10000-1712122205-dwd---bi*
# not relevant polygon removed
# (563,)
# 2017.12.13 -- 04:29:12
# 2017.12.13 -- 04:29:12
# /automount/radar/dwd/ry/2017/2017-12/2017-12-13/raa01-ry_10000-1712130430-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.13 -- 06:04:47
# 2017.12.13 -- 06:04:47
# /automount/radar/dwd/ry/2017/2017-12/2017-12-13/raa01-ry_10000-1712130605-dwd---bi*
# not relevant polygon removed
# (431,)
# 2017.12.13 -- 21:11:39
# 2017.12.13 -- 21:11:39
# /automount/radar/dwd/ry/2017/2017-12/2017-12-13/raa01-ry_10000-1712132110-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.13 -- 22:47:24
# 2017.12.13 -- 22:47:24
# /automount/radar/dwd/ry/2017/2017-12/2017-12-13/raa01-ry_10000-1712132245-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.14 -- 05:12:00
# 2017.12.14 -- 05:12:00
# /automount/radar/dwd/ry/2017/2017-12/2017-12-14/raa01-ry_10000-1712140510-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.12.14 -- 21:54:20
# 2017.12.14 -- 21:54:20
# /automount/radar/dwd/ry/2017/2017-12/2017-12-14/raa01-ry_10000-1712142155-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.12.15 -- 04:18:57
# 2017.12.15 -- 04:18:57
# /automount/radar/dwd/ry/2017/2017-12/2017-12-15/raa01-ry_10000-1712150420-dwd---bi*
# not relevant polygon removed
# (343,)
# 2017.12.15 -- 05:54:44
# 2017.12.15 -- 05:54:44
# /automount/radar/dwd/ry/2017/2017-12/2017-12-15/raa01-ry_10000-1712150555-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.15 -- 21:01:35
# 2017.12.15 -- 21:01:35
# /automount/radar/dwd/ry/2017/2017-12/2017-12-15/raa01-ry_10000-1712152100-dwd---bi*
# not relevant polygon removed
# (451,)
# 2017.12.15 -- 22:37:06
# 2017.12.15 -- 22:37:06
# /automount/radar/dwd/ry/2017/2017-12/2017-12-15/raa01-ry_10000-1712152235-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.16 -- 05:01:47
# 2017.12.16 -- 05:01:47
# /automount/radar/dwd/ry/2017/2017-12/2017-12-16/raa01-ry_10000-1712160500-dwd---bi*
# not relevant polygon removed
# (545,)
# 2017.12.16 -- 21:44:24
# 2017.12.16 -- 21:44:24
# /automount/radar/dwd/ry/2017/2017-12/2017-12-16/raa01-ry_10000-1712162145-dwd---bi*
# not relevant polygon removed
# (433,)
# 2017.12.17 -- 04:08:50
# 2017.12.17 -- 04:08:50
# /automount/radar/dwd/ry/2017/2017-12/2017-12-17/raa01-ry_10000-1712170410-dwd---bi*
# not relevant polygon removed
# (593,)
# 2017.12.17 -- 20:51:21
# 2017.12.17 -- 20:51:21
# /automount/radar/dwd/ry/2017/2017-12/2017-12-17/raa01-ry_10000-1712172050-dwd---bi*
# not relevant polygon removed
# (659,)
# 2017.12.18 -- 03:15:57
# 2017.12.18 -- 03:15:57
# /automount/radar/dwd/ry/2017/2017-12/2017-12-18/raa01-ry_10000-1712180315-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.18 -- 04:51:38
# 2017.12.18 -- 04:51:38
# /automount/radar/dwd/ry/2017/2017-12/2017-12-18/raa01-ry_10000-1712180450-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.18 -- 19:58:30
# 2017.12.18 -- 19:58:30
# /automount/radar/dwd/ry/2017/2017-12/2017-12-18/raa01-ry_10000-1712182055-dwd---bi*
# not relevant polygon removed
# (329,)
# 2017.12.18 -- 21:34:08
# 2017.12.18 -- 21:34:08
# /automount/radar/dwd/ry/2017/2017-12/2017-12-18/raa01-ry_10000-1712182135-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.19 -- 03:58:46
# 2017.12.19 -- 03:58:46
# /automount/radar/dwd/ry/2017/2017-12/2017-12-19/raa01-ry_10000-171219455-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.19 -- 20:41:19
# 2017.12.19 -- 20:41:19
# /automount/radar/dwd/ry/2017/2017-12/2017-12-19/raa01-ry_10000-1712192040-dwd---bi*
# not relevant polygon removed
# (555,)
# 2017.12.20 -- 03:05:40
# 2017.12.20 -- 03:05:40
# /automount/radar/dwd/ry/2017/2017-12/2017-12-20/raa01-ry_10000-1712200305-dwd---bi*
# not relevant polygon removed
# (483,)
# 2017.12.20 -- 19:48:16
# 2017.12.20 -- 19:48:16
# /automount/radar/dwd/ry/2017/2017-12/2017-12-20/raa01-ry_10000-1712201950-dwd---bi*
# not relevant polygon removed
# not relevant polygon removed
# (587,)
# 2017.12.21 -- 02:12:54
# 2017.12.21 -- 02:12:54
# /automount/radar/dwd/ry/2017/2017-12/2017-12-21/raa01-ry_10000-1712210210-dwd---bi*
# not relevant polygon removed
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.21 -- 03:48:29
# 2017.12.21 -- 03:48:29
# /automount/radar/dwd/ry/2017/2017-12/2017-12-21/raa01-ry_10000-1712210350-dwd---bi*
# not relevant polygon removed
# not relevant polygon removed
# (403,)
# 2017.12.21 -- 18:55:20
# 2017.12.21 -- 18:55:20
# /automount/radar/dwd/ry/2017/2017-12/2017-12-21/raa01-ry_10000-1712211855-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.21 -- 20:31:03
# 2017.12.21 -- 20:31:03
# /automount/radar/dwd/ry/2017/2017-12/2017-12-21/raa01-ry_10000-1712212030-dwd---bi*
# not relevant polygon removed
# (299,)
# 2017.12.22 -- 02:55:38
# 2017.12.22 -- 02:55:38
# /automount/radar/dwd/ry/2017/2017-12/2017-12-22/raa01-ry_10000-1712220255-dwd---bi*
# not relevant polygon removed
# (657,)
# 2017.12.22 -- 19:37:59
# 2017.12.22 -- 19:37:59
# /automount/radar/dwd/ry/2017/2017-12/2017-12-22/raa01-ry_10000-1712221935-dwd---bi*
# not relevant polygon removed
# (641,)
# 2017.12.23 -- 02:02:31
# 2017.12.23 -- 02:02:31
# /automount/radar/dwd/ry/2017/2017-12/2017-12-23/raa01-ry_10000-1712230200-dwd---bi*
# not relevant polygon removed
# (365,)
# 2017.12.23 -- 03:38:20
# 2017.12.23 -- 03:38:20
# /automount/radar/dwd/ry/2017/2017-12/2017-12-23/raa01-ry_10000-1712230340-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.23 -- 18:45:07
# 2017.12.23 -- 18:45:07
# /automount/radar/dwd/ry/2017/2017-12/2017-12-23/raa01-ry_10000-1712231845-dwd---bi*
# not relevant polygon removed
# (477,)
# 2017.12.24 -- 02:45:19
# 2017.12.24 -- 02:45:19
# /automount/radar/dwd/ry/2017/2017-12/2017-12-24/raa01-ry_10000-1712240245-dwd---bi*
# not relevant polygon removed
# (521,)
# 2017.12.24 -- 19:27:53
# 2017.12.24 -- 19:27:53
# /automount/radar/dwd/ry/2017/2017-12/2017-12-24/raa01-ry_10000-1712241925-dwd---bi*
# not relevant polygon removed
# (409,)
# 2017.12.25 -- 01:52:20
# 2017.12.25 -- 01:52:20
# /automount/radar/dwd/ry/2017/2017-12/2017-12-25/raa01-ry_10000-1712250150-dwd---bi*
# not relevant polygon removed
# (609,)
# 2017.12.25 -- 18:34:46
# 2017.12.25 -- 18:34:46
# /automount/radar/dwd/ry/2017/2017-12/2017-12-25/raa01-ry_10000-1712251835-dwd---bi*
# not relevant polygon removed
# (661,)
# 2017.12.26 -- 00:59:21
# 2017.12.26 -- 00:59:21
# /automount/radar/dwd/ry/2017/2017-12/2017-12-26/raa01-ry_10000-171226155-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.26 -- 02:35:02
# 2017.12.26 -- 02:35:02
# /automount/radar/dwd/ry/2017/2017-12/2017-12-26/raa01-ry_10000-1712260235-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.26 -- 17:41:53
# 2017.12.26 -- 17:41:53
# /automount/radar/dwd/ry/2017/2017-12/2017-12-26/raa01-ry_10000-1712261740-dwd---bi*
# not relevant polygon removed
# (353,)
# 2017.12.26 -- 19:17:28
# 2017.12.26 -- 19:17:28
# /automount/radar/dwd/ry/2017/2017-12/2017-12-26/raa01-ry_10000-1712261915-dwd---bi*
# not relevant polygon removed
# __________________________________________RY File Missing!
# 2017.12.27 -- 01:42:07
# 2017.12.27 -- 01:42:07
# /automount/radar/dwd/ry/2017/2017-12/2017-12-27/raa01-ry_10000-1712270140-dwd---bi*
# not relevant polygon removed
# (631,)
# 2017.12.27 -- 18:24:47
# 2017.12.27 -- 18:24:47
# /automount/radar/dwd/ry/2017/2017-12/2017-12-27/raa01-ry_10000-1712271825-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.28 -- 00:49:20
# 2017.12.28 -- 00:49:20
# /automount/radar/dwd/ry/2017/2017-12/2017-12-28/raa01-ry_10000-1712280050-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.28 -- 17:32:26
# 2017.12.28 -- 17:32:26
# /automount/radar/dwd/ry/2017/2017-12/2017-12-28/raa01-ry_10000-1712281730-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.28 -- 23:57:16
# 2017.12.28 -- 23:57:16
# /automount/radar/dwd/ry/2017/2017-12/2017-12-28/raa01-ry_10000-1712282355-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.29 -- 01:32:56
# 2017.12.29 -- 01:32:56
# /automount/radar/dwd/ry/2017/2017-12/2017-12-29/raa01-ry_10000-1712290130-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.29 -- 16:40:16
# 2017.12.29 -- 16:40:16
# /automount/radar/dwd/ry/2017/2017-12/2017-12-29/raa01-ry_10000-1712291640-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.29 -- 18:16:00
# 2017.12.29 -- 18:16:00
# /automount/radar/dwd/ry/2017/2017-12/2017-12-29/raa01-ry_10000-1712291815-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.30 -- 00:40:48
# 2017.12.30 -- 00:40:48
# /automount/radar/dwd/ry/2017/2017-12/2017-12-30/raa01-ry_10000-1712300040-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.30 -- 17:23:46
# 2017.12.30 -- 17:23:46
# /automount/radar/dwd/ry/2017/2017-12/2017-12-30/raa01-ry_10000-1712301725-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.30 -- 23:48:25
# 2017.12.30 -- 23:48:25
# /automount/radar/dwd/ry/2017/2017-12/2017-12-30/raa01-ry_10000-1712302350-dwd---bi*
# __________________________________________RY File Missing!
# 2017.12.31 -- 16:31:33
# 2017.12.31 -- 16:31:33
# /automount/radar/dwd/ry/2017/2017-12/2017-12-31/raa01-ry_10000-1712311630-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.01 -- 00:32:01
# 2018.01.01 -- 00:32:01
# /automount/radar/dwd/ry/2018/2018-01/2018-01-01/raa01-ry_10000-1801010030-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.01 -- 15:39:16
# 2018.01.01 -- 15:39:16
# /automount/radar/dwd/ry/2018/2018-01/2018-01-01/raa01-ry_10000-1801011540-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.01 -- 17:15:07
# 2018.01.01 -- 17:15:07
# /automount/radar/dwd/ry/2018/2018-01/2018-01-01/raa01-ry_10000-1801011715-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.01 -- 23:39:53
# 2018.01.01 -- 23:39:53
# /automount/radar/dwd/ry/2018/2018-01/2018-01-01/raa01-ry_10000-1801012340-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.02 -- 16:22:43
# 2018.01.02 -- 16:22:43
# /automount/radar/dwd/ry/2018/2018-01/2018-01-02/raa01-ry_10000-1801021620-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.02 -- 22:47:29
# 2018.01.02 -- 22:47:29
# /automount/radar/dwd/ry/2018/2018-01/2018-01-02/raa01-ry_10000-1801022245-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.03 -- 00:23:19
# 2018.01.03 -- 00:23:19
# /automount/radar/dwd/ry/2018/2018-01/2018-01-03/raa01-ry_10000-1801030025-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.03 -- 15:30:35
# 2018.01.03 -- 15:30:35
# /automount/radar/dwd/ry/2018/2018-01/2018-01-03/raa01-ry_10000-1801031530-dwd---bi*
# __________________________________________RY File Missing!
# 2018.01.03 -- 17:06:11
# 2018.01.03 -- 17:06:11
# /automount/radar/dwd/ry/2018/2018-01/2018-01-03/raa01-ry_10000-1801031705-dwd---bi*
# __________________________________________RY File Missing!
# CPU times: user 1h 8min 41s, sys: 1min 6s, total: 1h 9min 48s
# Wall time: 1h 8min 34s
